# %% [markdown]
# <a href="https://colab.research.google.com/github/mmuputisi/Adv-Py_Data_Analysis/blob/main/Non-linear%20ESG%20regression%20model%20with%20robustness%20checks%20FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# standalone_nonlinear_complete.py
"""
Complete Non-Linear Effects Model with Centered Approach
Analysis of quadratic, threshold, and other non-linear specifications
"""

# ============================================================================
# SETUP AND IMPORTS
# ============================================================================
from google.colab import drive
drive.mount('/content/drive')

# !pip install -q linearmodels pandas numpy matplotlib seaborn statsmodels

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from linearmodels.panel import PanelOLS
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.diagnostic import linear_reset, het_breuschpagan
import warnings
warnings.filterwarnings('ignore')

# ============================================================================
# CONFIGURATION
# ============================================================================
class Config:
    """Configuration for non-linear effects analysis"""
    PROJECT_DIR = '/content/drive/MyDrive/Colab Notebooks/FTSE Data'
    DATA_PATH = os.path.join(PROJECT_DIR, 'FTSE data.xlsx')
    OUTPUT_DIR = os.path.join(PROJECT_DIR, 'nonlinear_complete_outputs')

    # Consumer Staples firms (must match original)
    CONSUMER_STAPLES_FIRMS = [
        'Associated British Foods', 'British American Tobacco', 'Coca Cola HBC AG',
        'Diageo', 'J. Sainsbury', 'Reckitt Benckiser', 'Tesco', 'Unilever', 'Haleon Plc'
    ]

    # Analysis settings
    USE_CENTERED_APPROACH = True  # Set to True for centered, False for simple
    THRESHOLD_QUANTILES = [0.25, 0.5, 0.75, 0.9]
    CREATE_PLOTS = True
    SAVE_RESULTS = True

    # Output precision
    COEFF_DECIMALS = 6
    R2_DECIMALS = 6

# ============================================================================
# DATA LOADER WITH CENTERING
# ============================================================================
class DataLoaderWithCentering:
    """Load data with centered non-linear transformations"""

    def __init__(self, config):
        self.config = config
        self.df = None
        self.df_cs = None
        self.df_all = None
        self.esg_means = {}  # Store means for interpretation

    def load_and_prepare_all_transformations(self):
        """
        Load data and create ALL transformations (centered and simple)
        """
        print("Loading data and creating all non-linear transformations...")
        print("-" * 60)

        # 1. Load Excel file
        self.df = pd.read_excel(self.config.DATA_PATH)

        # 2. Set multi-index
        self.df = self.df.set_index(['Firm', 'Year']).sort_index()

        # 3. Rename Tobin's Q
        self.df = self.df.rename(columns={"Tobin's Q": "Tobin_Q"})

        # 4. Basic transformations
        self.df['Size'] = np.log(self.df['Total Assets'])
        self.df['Leverage'] = self.df['Total Liabilities'] / self.df['Total Assets']
        self.df['Tobin_Q_log'] = np.log(self.df['Tobin_Q'] + 0.001)

        # 5. Create lagged ESG variables
        print("Creating lagged ESG variables...")
        self.df['E_lag'] = self.df.groupby(level=0)['E'].shift(1)
        self.df['S_lag'] = self.df.groupby(level=0)['S'].shift(1)
        self.df['G_lag'] = self.df.groupby(level=0)['G'].shift(1)

        # 6. Create lagged controls
        self.df['ROA_lag'] = self.df.groupby(level=0)['ROA'].shift(1)
        self.df['Size_lag'] = self.df.groupby(level=0)['Size'].shift(1)
        self.df['Leverage_lag'] = self.df.groupby(level=0)['Leverage'].shift(1)

        # 7. Create sector variable
        print("Creating sector variable...")
        sectors = []
        for firm in self.df.index.get_level_values(0):
            if firm in self.config.CONSUMER_STAPLES_FIRMS:
                sectors.append('Consumer Staples')
            else:
                sectors.append('Other')

        self.df['Sector'] = sectors
        self.df['ConsumerStaples'] = (self.df['Sector'] == 'Consumer Staples').astype(int)

        # 8. CREATE NON-LINEAR TRANSFORMATIONS
        print("\nCreating non-linear transformations...")
        self.df = self._create_all_nonlinear_transformations(self.df)

        # 9. Create datasets
        self.df_cs = self.df[self.df['ConsumerStaples'] == 1].copy()
        self.df_all = self.df.copy()

        # Summary
        print("\n" + "="*60)
        print("DATA PREPARATION COMPLETE")
        print("="*60)
        print(f"Total observations: {len(self.df)}")
        print(f"Consumer Staples: {len(self.df_cs)}")
        print(f"Other sectors: {len(self.df_all) - len(self.df_cs)}")
        print(f"\nESG means (for centering):")
        for component, mean_val in self.esg_means.items():
            print(f"  {component}: {mean_val:.4f}")

        return self.df, self.df_cs, self.df_all

    def _create_all_nonlinear_transformations(self, df):
        """
        Create all non-linear transformations (centered and simple)
        """
        df = df.copy()

        # Define ESG components to transform
        esg_components = ['E_lag', 'S_lag', 'G_lag']

        print("\nA. CENTERED TRANSFORMATIONS (Recommended):")
        print("-" * 40)

        for component in esg_components:
            if component in df.columns:
                # Calculate and store mean
                mean_val = df[component].mean()
                self.esg_means[component] = mean_val

                # 1. Centered variable
                df[f'{component}_centered'] = df[component] - mean_val

                # 2. Centered squared
                df[f'{component}_sq_centered'] = df[f'{component}_centered'] ** 2

                # 3. Centered cubic
                df[f'{component}_cube_centered'] = df[f'{component}_centered'] ** 3

                print(f"  ✓ {component}_centered = {component} - {mean_val:.4f}")
                print(f"  ✓ {component}_sq_centered = ({component}_centered)²")
                print(f"  ✓ {component}_cube_centered = ({component}_centered)³")

        print("\nB. SIMPLE TRANSFORMATIONS (for comparison):")
        print("-" * 40)

        for component in esg_components:
            if component in df.columns:
                # 1. Simple squared
                df[f'{component}_sq'] = df[component] ** 2

                # 2. Simple cubic
                df[f'{component}_cube'] = df[component] ** 3

                # 3. Logarithmic (with small constant)
                min_val = df[component].min()
                constant = 1 - min_val if min_val < 1 else 0.001
                df[f'log_{component}'] = np.log(df[component] + constant)

                # 4. Square root
                shift = -min_val + 0.001 if min_val < 0 else 0
                df[f'sqrt_{component}'] = np.sqrt(df[component] + shift)

                print(f"  ✓ {component}_sq = ({component})²")
                print(f"  ✓ log_{component} = ln({component} + {constant:.3f})")

        print("\nC. THRESHOLD VARIABLES:")
        print("-" * 40)

        for component in esg_components:
            if component in df.columns:
                for q in self.config.THRESHOLD_QUANTILES:
                    try:
                        threshold = df[component].quantile(q)
                        df[f'{component}_above{q*100:.0f}'] = (df[component] > threshold).astype(int)
                        print(f"  ✓ {component}_above{q*100:.0f}: 1 if > {threshold:.4f}")
                    except:
                        pass

        print("\nD. INTERACTION TERMS (centered):")
        print("-" * 40)

        centered_components = [f'{c}_centered' for c in esg_components]
        for i in range(len(centered_components)):
            for j in range(i+1, len(centered_components)):
                var1, var2 = centered_components[i], centered_components[j]
                df[f'{var1}_{var2}_interact'] = df[var1] * df[var2]
                print(f"  ✓ {var1}_{var2}_interact = {var1} × {var2}")

        print(f"\n✓ Created {sum(['centered' in col or '_sq' in col or 'log_' in col or
                               'sqrt_' in col or '_above' in col or '_interact' in col
                               for col in df.columns])} non-linear transformations")

        return df

    def get_recommended_variables(self, centered=True):
        """
        Get recommended variable sets based on approach
        """
        if centered:
            return {
                'quadratic': ['E_lag_centered', 'E_lag_sq_centered',
                             'S_lag_centered', 'S_lag_sq_centered',
                             'G_lag_centered', 'G_lag_sq_centered'],
                'cubic': ['E_lag_centered', 'E_lag_sq_centered', 'E_lag_cube_centered',
                         'S_lag_centered', 'S_lag_sq_centered', 'S_lag_cube_centered',
                         'G_lag_centered', 'G_lag_sq_centered', 'G_lag_cube_centered'],
                'logarithmic': ['log_E_lag', 'log_S_lag', 'log_G_lag'],
                'sqrt': ['sqrt_E_lag', 'sqrt_S_lag', 'sqrt_G_lag']
            }
        else:
            return {
                'quadratic': ['E_lag', 'E_lag_sq', 'S_lag', 'S_lag_sq', 'G_lag', 'G_lag_sq'],
                'cubic': ['E_lag', 'E_lag_sq', 'E_lag_cube',
                         'S_lag', 'S_lag_sq', 'S_lag_cube',
                         'G_lag', 'G_lag_sq', 'G_lag_cube'],
                'logarithmic': ['log_E_lag', 'log_S_lag', 'log_G_lag'],
                'sqrt': ['sqrt_E_lag', 'sqrt_S_lag', 'sqrt_G_lag']
            }

# ============================================================================
# NON-LINEAR MODEL ANALYZER
# ============================================================================
class NonlinearEffectsAnalyzerComplete:
    """Complete non-linear effects analyzer with diagnostics"""

    def __init__(self, config):
        self.config = config
        self.loader = DataLoaderWithCentering(config)
        self.results = {}
        self.diagnostics = {}

    def run_complete_analysis(self, sector='cs', y_var='Tobin_Q',
                             use_centered=None, run_diagnostics=True):
        """
        Run complete non-linear analysis

        Parameters:
        -----------
        sector : str
            'cs' for Consumer Staples, 'all' for All Sectors
        y_var : str
            Dependent variable ('Tobin_Q' or 'Tobin_Q_log')
        use_centered : bool or None
            True for centered, False for simple, None for config default
        run_diagnostics : bool
            Whether to run model diagnostics
        """
        # Determine approach
        if use_centered is None:
            use_centered = self.config.USE_CENTERED_APPROACH

        approach = "CENTERED" if use_centered else "SIMPLE"

        print("\n" + "="*80)
        print(f"COMPLETE NON-LINEAR ANALYSIS - {approach} APPROACH")
        print(f"Sector: {'Consumer Staples' if sector == 'cs' else 'All Sectors'}")
        print(f"Dependent: {y_var}")
        print("="*80)

        # Load data with all transformations
        df, df_cs, df_all = self.loader.load_and_prepare_all_transformations()

        # Select dataset
        if sector == 'cs':
            analysis_df = df_cs.copy()
            sector_name = 'Consumer Staples Only'
            control_vars = ['ROA', 'Size', 'Leverage']
        else:
            analysis_df = df_all.copy()
            sector_name = 'All Sectors'
            control_vars = ['ROA', 'Size', 'Leverage', 'ConsumerStaples']

        # Get variable sets
        var_sets = self.loader.get_recommended_variables(centered=use_centered)

        # Run all model specifications
        print(f"\nRunning model specifications ({approach} approach)...")

        all_results = {}

        # 1. Quadratic model (main specification)
        print(f"\n1. QUADRATIC MODEL:")
        quad_results = self._run_model_specification(
            analysis_df, y_var, var_sets['quadratic'], control_vars,
            'quadratic', sector_name, use_centered
        )
        if quad_results:
            all_results['quadratic'] = quad_results

        # 2. Cubic model
        print(f"\n2. CUBIC MODEL:")
        cubic_results = self._run_model_specification(
            analysis_df, y_var, var_sets['cubic'], control_vars,
            'cubic', sector_name, use_centered
        )
        if cubic_results:
            all_results['cubic'] = cubic_results

        # 3. Logarithmic model
        print(f"\n3. LOGARITHMIC MODEL:")
        log_results = self._run_model_specification(
            analysis_df, y_var, var_sets['logarithmic'], control_vars,
            'logarithmic', sector_name, use_centered
        )
        if log_results:
            all_results['logarithmic'] = log_results

        # 4. Square root model
        print(f"\n4. SQUARE ROOT MODEL:")
        sqrt_results = self._run_model_specification(
            analysis_df, y_var, var_sets['sqrt'], control_vars,
            'square_root', sector_name, use_centered
        )
        if sqrt_results:
            all_results['sqrt'] = sqrt_results

        # 5. Threshold models
        print(f"\n5. THRESHOLD MODELS:")
        threshold_results = self._run_threshold_models(
            analysis_df, y_var, control_vars, sector_name
        )
        if threshold_results:
            all_results['threshold'] = threshold_results

        # 6. Interaction model
        print(f"\n6. INTERACTION MODEL:")
        interaction_results = self._run_interaction_model(
            analysis_df, y_var, control_vars, sector_name, use_centered
        )
        if interaction_results:
            all_results['interaction'] = interaction_results

        # Model comparison
        print(f"\n7. MODEL COMPARISON:")
        comparison_df = self._compare_models(all_results)

        # Best model selection
        print(f"\n8. BEST MODEL SELECTION:")
        best_model_info = self._select_best_model(all_results)

        # Run diagnostics if requested
        if run_diagnostics and best_model_info:
            print(f"\n9. MODEL DIAGNOSTICS (Best Model):")
            self._run_complete_diagnostics(best_model_info, analysis_df)

        # Create summary table
        print(f"\n10. FINAL SUMMARY:")
        self._create_final_summary(all_results, best_model_info,
                                 comparison_df, sector_name, y_var, use_centered)

        return {
            'all_results': all_results,
            'best_model': best_model_info,
            'comparison': comparison_df,
            'sector': sector_name,
            'y_var': y_var,
            'approach': approach,
            'data': analysis_df
        }

    def _run_model_specification(self, df, y_var, esg_vars, control_vars,
                               model_type, sector_name, centered):
        """Run a single model specification"""
        # Prepare all variables
        all_vars = esg_vars + control_vars + [y_var]
        df_clean = df.dropna(subset=all_vars)

        if len(df_clean) < 10:
            print(f"  ⚠ Insufficient data: {len(df_clean)} observations")
            return None

        # Check VIF before running
        vif_info = self._calculate_vif(df_clean, esg_vars)

        print(f"  N = {len(df_clean)}, Variables = {len(esg_vars)}")
        print(f"  Max VIF = {vif_info['max_vif']:.2f}")

        if vif_info['max_vif'] > 10:
            print(f"  ⚠ High multicollinearity (VIF > 10)")

        # Run regression
        y = df_clean[y_var]
        X = df_clean[esg_vars + control_vars]
        X = pd.concat([pd.Series(1, index=X.index, name='const'), X], axis=1)

        try:
            model = PanelOLS(y, X, entity_effects=False, time_effects=False)
            results = model.fit(cov_type='robust')

            # Calculate turning points for quadratic/cubic models
            turning_points = None
            if 'quadratic' in model_type:
                turning_points = self._calculate_turning_points(
                    results, df_clean, esg_vars, centered
                )
            elif 'cubic' in model_type:
                turning_points = self._calculate_inflection_points(
                    results, df_clean, esg_vars, centered
                )

            # Store results
            result_info = {
                'model_type': model_type,
                'results': results,
                'esg_vars': esg_vars,
                'control_vars': control_vars,
                'nobs': results.nobs,
                'r2': results.rsquared,
                'r2_adj': results.rsquared_adj if hasattr(results, 'rsquared_adj') else results.rsquared,
                'vif_max': vif_info['max_vif'],
                'vif_details': vif_info,
                'turning_points': turning_points,
                'centered': centered,
                'sector': sector_name,
                'y_var': y_var,
                'data': df_clean
            }

            # Print detailed results
            self._print_model_details(result_info)

            # Store in global results
            key = f"{model_type}_{'centered' if centered else 'simple'}_{sector_name.replace(' ', '_')}_{y_var}"
            self.results[key] = result_info

            return result_info

        except Exception as e:
            print(f"  ✗ Error: {str(e)[:100]}")
            return None

    def _run_threshold_models(self, df, y_var, control_vars, sector_name):
        """Run threshold models with different cutoffs"""
        threshold_results = {}

        for component in ['E_lag', 'S_lag', 'G_lag']:
            for q in self.config.THRESHOLD_QUANTILES:
                threshold_var = f'{component}_above{q*100:.0f}'

                if threshold_var in df.columns:
                    # Prepare variables
                    esg_vars = [threshold_var]
                    all_vars = esg_vars + control_vars + [y_var]
                    df_clean = df.dropna(subset=all_vars)

                    if len(df_clean) < 10:
                        continue

                    # Run regression
                    y = df_clean[y_var]
                    X = df_clean[esg_vars + control_vars]
                    X = pd.concat([pd.Series(1, index=X.index, name='const'), X], axis=1)

                    try:
                        model = PanelOLS(y, X, entity_effects=False, time_effects=False)
                        results = model.fit(cov_type='robust')

                        # Store
                        key = f"threshold_{component}_q{q*100:.0f}"
                        threshold_results[key] = {
                            'model_type': 'threshold',
                            'results': results,
                            'component': component,
                            'quantile': q,
                            'threshold_var': threshold_var,
                            'nobs': results.nobs,
                            'r2': results.rsquared
                        }

                        # Print if significant
                        if threshold_var in results.params:
                            coeff = results.params[threshold_var]
                            pval = results.pvalues.get(threshold_var, 1.0)
                            if pval < 0.10:
                                threshold_val = df[component].quantile(q)
                                print(f"  ✓ {component} > {threshold_val:.2f}: β = {coeff:.4f} (p={pval:.3f})")

                    except:
                        pass

        return threshold_results

    def _run_interaction_model(self, df, y_var, control_vars, sector_name, centered):
        """Run interaction model"""
        # Define base variables
        if centered:
            base_vars = ['E_lag_centered', 'S_lag_centered', 'G_lag_centered']
            interactions = ['E_lag_centered_S_lag_centered_interact',
                           'E_lag_centered_G_lag_centered_interact',
                           'S_lag_centered_G_lag_centered_interact']
        else:
            base_vars = ['E_lag', 'S_lag', 'G_lag']
            # Create interactions if they don't exist
            interactions = []
            for i in range(len(base_vars)):
                for j in range(i+1, len(base_vars)):
                    var1, var2 = base_vars[i], base_vars[j]
                    inter_var = f'{var1}_{var2}_interact'
                    if inter_var not in df.columns:
                        df[inter_var] = df[var1] * df[var2]
                    interactions.append(inter_var)

        # Prepare all variables
        esg_vars = base_vars + interactions
        all_vars = esg_vars + control_vars + [y_var]
        df_clean = df.dropna(subset=all_vars)

        if len(df_clean) < 10:
            print(f"  ⚠ Insufficient data")
            return None

        # Run regression
        y = df_clean[y_var]
        X = df_clean[esg_vars + control_vars]
        X = pd.concat([pd.Series(1, index=X.index, name='const'), X], axis=1)

        try:
            model = PanelOLS(y, X, entity_effects=False, time_effects=False)
            results = model.fit(cov_type='robust')

            # Calculate marginal effects
            marginal_effects = {}
            for component in ['E', 'S', 'G']:
                base_var = f'{component}_lag_centered' if centered else f'{component}_lag'
                if base_var in results.params:
                    base_effect = results.params[base_var]
                    interaction_effect = 0

                    # Sum interaction effects
                    for other in ['E', 'S', 'G']:
                        if other != component:
                            other_var = f'{other}_lag_centered' if centered else f'{other}_lag'
                            inter_var = f'{base_var}_{other_var}_interact'
                            if inter_var in results.params:
                                other_mean = df_clean[other_var].mean()
                                interaction_effect += results.params[inter_var] * other_mean

                    marginal_effects[component] = {
                        'base_effect': base_effect,
                        'interaction_effect': interaction_effect,
                        'total_marginal_effect': base_effect + interaction_effect
                    }

            # Store results
            result_info = {
                'model_type': 'interaction',
                'results': results,
                'esg_vars': esg_vars,
                'control_vars': control_vars,
                'nobs': results.nobs,
                'r2': results.rsquared,
                'r2_adj': results.rsquared_adj if hasattr(results, 'rsquared_adj') else results.rsquared,
                'marginal_effects': marginal_effects,
                'centered': centered,
                'sector': sector_name,
                'y_var': y_var
            }

            # Print summary
            print(f"  N = {results.nobs}, R² = {results.rsquared:.6f}")
            if marginal_effects:
                for component, effects in marginal_effects.items():
                    print(f"  {component}: Marginal effect = {effects['total_marginal_effect']:.6f}")

            return result_info

        except Exception as e:
            print(f"  ✗ Error: {e}")
            return None

    def _calculate_vif(self, df, variables):
        """Calculate Variance Inflation Factors"""
        X_data = df[variables].dropna()

        if len(X_data) < 2:
            return {'max_vif': 0, 'details': {}}

        vif_details = {}
        for i, var in enumerate(variables):
            try:
                vif = variance_inflation_factor(X_data.values, i)
                vif_details[var] = vif
            except:
                vif_details[var] = np.nan

        valid_vifs = [v for v in vif_details.values() if not np.isnan(v)]
        max_vif = max(valid_vifs) if valid_vifs else 0

        return {
            'max_vif': max_vif,
            'details': vif_details,
            'high_vif_vars': [var for var, vif in vif_details.items()
                            if vif > 10 and not np.isnan(vif)]
        }

    def _calculate_turning_points(self, results, df, esg_vars, centered):
        """Calculate turning points for quadratic models"""
        turning_points = {}

        # Extract component from variable names
        for component in ['E', 'S', 'G']:
            # Find linear and quadratic variables for this component
            linear_var = None
            quad_var = None

            for var in esg_vars:
                if component in var:
                    if '_sq' in var or 'sq_' in var:
                        quad_var = var
                    elif 'cube' not in var:  # Exclude cubic
                        linear_var = var

            if linear_var and quad_var:
                if linear_var in results.params and quad_var in results.params:
                    beta1 = results.params[linear_var]
                    beta2 = results.params[quad_var]

                    if beta2 != 0:
                        turning_point_raw = -beta1 / (2 * beta2)

                        # Adjust for centering
                        if centered and '_centered' in linear_var:
                            # Get original variable name
                            orig_var = linear_var.replace('_centered', '')
                            if orig_var in df.columns:
                                mean_val = df[orig_var].mean()
                                turning_point = turning_point_raw + mean_val
                            else:
                                turning_point = turning_point_raw
                        else:
                            turning_point = turning_point_raw

                        # Check if within data range
                        if '_centered' in linear_var:
                            check_var = linear_var.replace('_centered', '')
                        else:
                            check_var = linear_var

                        if check_var in df.columns:
                            data_min = df[check_var].min()
                            data_max = df[check_var].max()
                            within_range = data_min <= turning_point <= data_max

                            shape = "U-shaped (convex)" if beta2 > 0 else "Inverted U-shaped (concave)"

                            turning_points[component] = {
                                'turning_point': turning_point,
                                'turning_point_raw': turning_point_raw,
                                'shape': shape,
                                'beta1': beta1,
                                'beta2': beta2,
                                'within_range': within_range,
                                'data_range': [data_min, data_max]
                            }

        return turning_points

    def _calculate_inflection_points(self, results, df, esg_vars, centered):
        """Calculate inflection points for cubic models"""
        inflection_points = {}

        for component in ['E', 'S', 'G']:
            # Find variables for this component
            linear_var = None
            quad_var = None
            cube_var = None

            for var in esg_vars:
                if component in var:
                    if 'cube' in var:
                        cube_var = var
                    elif '_sq' in var or 'sq_' in var:
                        quad_var = var
                    else:
                        linear_var = var

            if linear_var and quad_var and cube_var:
                if all(v in results.params for v in [linear_var, quad_var, cube_var]):
                    beta1 = results.params[linear_var]
                    beta2 = results.params[quad_var]
                    beta3 = results.params[cube_var]

                    if beta3 != 0:
                        # Inflection point: x = -beta2/(3*beta3)
                        inflection_point_raw = -beta2 / (3 * beta3)

                        # Adjust for centering
                        if centered and '_centered' in linear_var:
                            orig_var = linear_var.replace('_centered', '')
                            if orig_var in df.columns:
                                mean_val = df[orig_var].mean()
                                inflection_point = inflection_point_raw + mean_val
                            else:
                                inflection_point = inflection_point_raw
                        else:
                            inflection_point = inflection_point_raw

                        inflection_points[component] = {
                            'inflection_point': inflection_point,
                            'inflection_point_raw': inflection_point_raw,
                            'beta1': beta1,
                            'beta2': beta2,
                            'beta3': beta3
                        }

        return inflection_points

    def _print_model_details(self, result_info):
        """Print detailed model results"""
        results = result_info['results']

        print(f"  R² = {results.rsquared:.{self.config.R2_DECIMALS}f}, "
              f"Adj. R² = {result_info['r2_adj']:.{self.config.R2_DECIMALS}f}")

        # Print key coefficients
        print(f"  Key coefficients:")
        for var in result_info['esg_vars'][:3]:  # First 3 ESG variables
            if var in results.params:
                coeff = results.params[var]
                pval = results.pvalues.get(var, 1.0)
                sig = "***" if pval < 0.01 else "**" if pval < 0.05 else "*" if pval < 0.10 else ""
                print(f"    {var}: {coeff:.{self.config.COEFF_DECIMALS}f}{sig}")

        # Print turning points if available
        if result_info.get('turning_points'):
            print(f"  Turning points:")
            for component, info in result_info['turning_points'].items():
                print(f"    {component}: {info['shape']} at {info['turning_point']:.4f}")

    def _compare_models(self, all_results):
        """Compare all model specifications"""
        if not all_results:
            return None

        comparison_data = []

        for model_type, result_info in all_results.items():
            if isinstance(result_info, dict) and 'results' in result_info:
                results = result_info['results']

                comparison_data.append({
                    'Model': result_info['model_type'].replace('_', ' ').title(),
                    'Approach': 'Centered' if result_info.get('centered', False) else 'Simple',
                    'N': result_info['nobs'],
                    'R²': result_info['r2'],
                    'Adj. R²': result_info['r2_adj'],
                    'Max VIF': result_info.get('vif_max', np.nan),
                    'AIC': self._calculate_aic(results),
                    'BIC': self._calculate_bic(results),
                    'ESG Vars': len(result_info['esg_vars'])
                })

        comparison_df = pd.DataFrame(comparison_data)

        if not comparison_df.empty:
            # Sort by R²
            comparison_df = comparison_df.sort_values('R²', ascending=False)

            print(f"\n{'Model':<20} {'Approach':<10} {'N':>6} {'R²':>12} {'Adj. R²':>12} {'Max VIF':>10} {'AIC':>12} {'BIC':>12}")
            print("-" * 110)

            for _, row in comparison_df.iterrows():
                print(f"{row['Model']:<20} {row['Approach']:<10} {row['N']:>6} "
                      f"{row['R²']:>12.{self.config.R2_DECIMALS}f} "
                      f"{row['Adj. R²']:>12.{self.config.R2_DECIMALS}f} "
                      f"{row['Max VIF']:>10.2f} "
                      f"{row['AIC']:>12.1f} {row['BIC']:>12.1f}")

        return comparison_df

    def _select_best_model(self, all_results):
        """Select best model using multiple criteria"""
        if not all_results:
            return None

        # Convert to list for easier processing
        model_list = []
        for model_type, result_info in all_results.items():
            if isinstance(result_info, dict) and 'results' in result_info:
                model_list.append({
                    'type': model_type,
                    'info': result_info,
                    'r2': result_info['r2'],
                    'bic': self._calculate_bic(result_info['results']),
                    'vif': result_info.get('vif_max', np.nan)
                })

        if not model_list:
            return None

        # Find best by different criteria
        best_by_r2 = max(model_list, key=lambda x: x['r2'])
        best_by_bic = min(model_list, key=lambda x: x['bic'])
        best_by_vif = min(model_list, key=lambda x: x['vif'])

        print(f"\nBest by R²: {best_by_r2['type']} (R² = {best_by_r2['r2']:.6f})")
        print(f"Best by BIC: {best_by_bic['type']} (BIC = {best_by_bic['bic']:.1f})")
        print(f"Best by VIF: {best_by_vif['type']} (VIF = {best_by_vif['vif']:.2f})")

        # Recommendation: Prioritize BIC (most conservative)
        recommendation = best_by_bic

        print(f"\nRECOMMENDED MODEL: {recommendation['type'].upper()}")
        print(f"  • R² = {recommendation['r2']:.6f}")
        print(f"  • BIC = {recommendation['bic']:.1f}")
        print(f"  • Max VIF = {recommendation['vif']:.2f}")
        print(f"  • Approach: {'Centered' if recommendation['info'].get('centered', False) else 'Simple'}")

        return recommendation['info']

    def _run_complete_diagnostics(self, model_info, df):
        """Run complete model diagnostics"""
        results = model_info['results']

        # 1. Multicollinearity (already calculated)
        print(f"\n1. Multicollinearity (VIF):")
        print(f"   Max VIF: {model_info.get('vif_max', 'N/A'):.2f}")
        if model_info.get('vif_details', {}).get('high_vif_vars'):
            print(f"   High VIF variables: {model_info['vif_details']['high_vif_vars']}")

        # 2. Functional form test (RESET)
        print(f"\n2. Functional Form (RESET test):")
        try:
            reset_result = linear_reset(results, power=2, test_type='fitted')
            print(f"   F-statistic: {reset_result.statistic:.4f}")
            print(f"   p-value: {reset_result.pvalue:.4f}")

            if reset_result.pvalue < 0.05:
                print(f"   ⚠ Reject linearity (supports non-linear specification)")
            else:
                print(f"   ✓ Cannot reject linearity")
        except Exception as e:
            print(f"   Could not perform RESET test: {str(e)[:50]}")

        # 3. Heteroskedasticity
        print(f"\n3. Heteroskedasticity (Breusch-Pagan):")
        try:
            bp_test = het_breuschpagan(results.resids, results.model.exog.dataframe)
            print(f"   LM statistic: {bp_test[0]:.4f}")
            print(f"   p-value: {bp_test[1]:.4f}")

            if bp_test[1] < 0.05:
                print(f"   ⚠ Evidence of heteroskedasticity (robust SE used)")
            else:
                print(f"   ✓ No evidence of heteroskedasticity")
        except:
            print(f"   Could not perform Breusch-Pagan test")

        # 4. Normality of residuals
        print(f"\n4. Normality of Residuals:")
        try:
            from scipy import stats
            residuals = results.resids

            # Jarque-Bera test
            jb_stat, jb_pval = stats.jarque_bera(residuals)
            print(f"   Jarque-Bera: {jb_stat:.4f} (p={jb_pval:.4f})")

            if jb_pval < 0.05:
                print(f"   ⚠ Reject normality of residuals")
            else:
                print(f"   ✓ Cannot reject normality")
        except:
            print(f"   Could not perform normality test")

    def _create_final_summary(self, all_results, best_model, comparison_df,
                            sector_name, y_var, use_centered):
        """Create final summary of analysis"""
        print("\n" + "="*80)
        print("FINAL ANALYSIS SUMMARY")
        print("="*80)

        print(f"\nAnalysis Details:")
        print(f"  • Sector: {sector_name}")
        print(f"  • Dependent variable: {y_var}")
        print(f"  • Approach: {'Centered (recommended)' if use_centered else 'Simple'}")
        print(f"  • Models tested: {len(all_results)}")

        if best_model:
            print(f"\nBest Model: {best_model['model_type'].upper()}")
            print(f"  • R²: {best_model['r2']:.{self.config.R2_DECIMALS}f}")
            print(f"  • Adjusted R²: {best_model['r2_adj']:.{self.config.R2_DECIMALS}f}")
            print(f"  • Observations: {best_model['nobs']}")
            print(f"  • Max VIF: {best_model.get('vif_max', 'N/A'):.2f}")

            # Print key findings
            if best_model['model_type'] == 'quadratic' and best_model.get('turning_points'):
                print(f"\nKey Findings (Quadratic Model):")
                for component, info in best_model['turning_points'].items():
                    print(f"  • {component}: {info['shape']}")
                    print(f"    Turning point: {info['turning_point']:.4f}")
                    print(f"    Within data range: {'Yes' if info['within_range'] else 'No'}")

            elif best_model['model_type'] == 'interaction' and best_model.get('marginal_effects'):
                print(f"\nKey Findings (Interaction Model):")
                for component, effects in best_model['marginal_effects'].items():
                    print(f"  • {component}: Total marginal effect = {effects['total_marginal_effect']:.6f}")

        # Save results if requested
        if self.config.SAVE_RESULTS:
            self._save_all_results(all_results, comparison_df, sector_name, y_var)

    def _save_all_results(self, all_results, comparison_df, sector_name, y_var):
        """Save all results to Excel"""
        os.makedirs(self.config.OUTPUT_DIR, exist_ok=True)

        # Create filename
        filename = f"nonlinear_results_{sector_name.replace(' ', '_')}_{y_var}.xlsx"
        filepath = os.path.join(self.config.OUTPUT_DIR, filename)

        with pd.ExcelWriter(filepath, engine='openpyxl') as writer:
            # 1. Model comparison
            if comparison_df is not None:
                comparison_df.to_excel(writer, sheet_name='Model_Comparison', index=False)

            # 2. Detailed results for each model
            for i, (model_type, result_info) in enumerate(all_results.items()):
                if isinstance(result_info, dict) and 'results' in result_info:
                    # Create coefficient table
                    results = result_info['results']

                    coeff_df = pd.DataFrame({
                        'Variable': results.params.index,
                        'Coefficient': results.params.values,
                        'Std_Error': [results.std_errors.get(v, np.nan) for v in results.params.index],
                        't_Stat': [results.tstats.get(v, np.nan) for v in results.params.index],
                        'P_Value': [results.pvalues.get(v, np.nan) for v in results.params.index]
                    })

                    # Limit sheet name length
                    sheet_name = f"{model_type}_{i}"[:31]
                    coeff_df.to_excel(writer, sheet_name=sheet_name, index=False)

            # 3. Summary statistics
            summary_data = []
            for model_type, result_info in all_results.items():
                if isinstance(result_info, dict) and 'results' in result_info:
                    summary_data.append({
                        'Model': model_type,
                        'Approach': 'Centered' if result_info.get('centered', False) else 'Simple',
                        'N': result_info['nobs'],
                        'R2': result_info['r2'],
                        'Adj_R2': result_info['r2_adj'],
                        'Max_VIF': result_info.get('vif_max', np.nan)
                    })

            if summary_data:
                summary_df = pd.DataFrame(summary_data)
                summary_df.to_excel(writer, sheet_name='Summary', index=False)

        print(f"\n✓ All results saved to: {filepath}")
        return filepath

    def _calculate_aic(self, results):
        """Calculate Akaike Information Criterion"""
        n = results.nobs
        k = len(results.params)
        ssr = getattr(results, 'ssr', None)

        if ssr is None:
            # Estimate SSR from residuals
            y_pred = results.predict().fitted_values
            y_actual = results.model.dependent.dataframe.iloc[:, 0]
            ssr = np.sum((y_actual - y_pred) ** 2)

        return n * np.log(ssr/n) + 2 * k

    def _calculate_bic(self, results):
        """Calculate Bayesian Information Criterion"""
        n = results.nobs
        k = len(results.params)
        ssr = getattr(results, 'ssr', None)

        if ssr is None:
            # Estimate SSR from residuals
            y_pred = results.predict().fitted_values
            y_actual = results.model.dependent.dataframe.iloc[:, 0]
            ssr = np.sum((y_actual - y_pred) ** 2)

        return n * np.log(ssr/n) + k * np.log(n)

# ============================================================================
# MAIN EXECUTION
# ============================================================================
def main():
    """Main execution function"""
    print("\n" + "="*80)
    print("COMPLETE NON-LINEAR EFFECTS ANALYSIS")
    print("With Centered and Simple Approaches")
    print("="*80)

    # Initialize configuration
    config = Config()

    # Create output directory
    os.makedirs(config.OUTPUT_DIR, exist_ok=True)

    # Initialize analyzer
    analyzer = NonlinearEffectsAnalyzerComplete(config)

    # Run analysis for Consumer Staples (recommended for non-linear)
    print("\n" + "="*80)
    print("ANALYSIS 1: CONSUMER STAPLES (Recommended for non-linear effects)")
    print("="*80)

    results_cs = analyzer.run_complete_analysis(
        sector='cs',
        y_var='Tobin_Q',
        use_centered=config.USE_CENTERED_APPROACH,
        run_diagnostics=True
    )

    # Run analysis for All Sectors (for comparison)
    print("\n" + "="*80)
    print("ANALYSIS 2: ALL SECTORS (Comparison)")
    print("="*80)

    results_all = analyzer.run_complete_analysis(
        sector='all',
        y_var='Tobin_Q',
        use_centered=config.USE_CENTERED_APPROACH,
        run_diagnostics=False  # Skip diagnostics for comparison
    )

    # Run with log-transformed Tobin's Q (robustness)
    print("\n" + "="*80)
    print("ANALYSIS 3: LOG-TRANSFORMED TOBIN'S Q (Robustness)")
    print("="*80)

    results_log = analyzer.run_complete_analysis(
        sector='cs',
        y_var='Tobin_Q_log',
        use_centered=config.USE_CENTERED_APPROACH,
        run_diagnostics=False
    )

    print("\n" + "="*80)
    print("ANALYSIS COMPLETE")
    print("="*80)

    print(f"\nSummary:")
    print(f"  • Output directory: {config.OUTPUT_DIR}")
    print(f"  • Approach used: {'CENTERED (recommended)' if config.USE_CENTERED_APPROACH else 'SIMPLE'}")
    print(f"  • Models run: {len(analyzer.results)}")
    print(f"  • Files saved: Check {config.OUTPUT_DIR}")

    return analyzer, results_cs, results_all, results_log

# ============================================================================
# EXECUTION
# ============================================================================
if __name__ == "__main__":
    analyzer, results_cs, results_all, results_log = main()

# standalone_nonlinear_with_robustness_fixed2.py
"""
Complete Non-Linear Effects Model with Robustness Checks
- Original code preserved exactly
- Robustness checks appended after main()
- Shows R² comparisons and sign/significance consistency
"""


# ============================================================================
# ROBUSTNESS CHECKS FOR NON-LINEAR MODELS
# ============================================================================
print("\n" + "="*100)
print("ROBUSTNESS CHECKS FOR NON-LINEAR MODELS")
print("="*100)
print("Testing sensitivity to dependent variable transformations")
print("Using EXACT same data samples as main program for each model")

# Get the original dataframes from analyzer
df = analyzer.loader.df
df_cs = analyzer.loader.df_cs
df_all = analyzer.loader.df_all

# First, capture the original results and data samples
print("\n" + "-"*60)
print("ORIGINAL MODEL RESULTS (FROM MAIN PROGRAM)")
print("-"*60)

original_results = {}
original_data_samples = {}  # Store the exact data used in each model

# Available transformations in the data
available_transforms = ['Tobin_Q_log', 'Tobin_Q_sqrt', 'Tobin_Q_inv', 'Tobin_Q_boxcox']

# Check which transformations exist
print("\nAvailable transformations in data:")
for trans in available_transforms:
    if trans in df.columns:
        print(f"  ✓ {trans}")
    else:
        print(f"  ✗ {trans}")

# Create missing transformations if needed
from scipy import stats

if 'Tobin_Q_sqrt' not in df.columns:
    df['Tobin_Q_sqrt'] = np.sqrt(df['Tobin_Q'].clip(lower=0))
    print("✓ Created Tobin_Q_sqrt")

if 'Tobin_Q_inv' not in df.columns:
    with np.errstate(divide='ignore', invalid='ignore'):
        df['Tobin_Q_inv'] = 1 / df['Tobin_Q']
        df['Tobin_Q_inv'] = df['Tobin_Q_inv'].replace([np.inf, -np.inf], np.nan)
    print("✓ Created Tobin_Q_inv")

if 'Tobin_Q_boxcox' not in df.columns:
    try:
        if (df['Tobin_Q'].dropna() > 0).all():
            boxcox_data, lambda_param = stats.boxcox(df['Tobin_Q'].dropna() + 0.001)
            df['Tobin_Q_boxcox'] = np.nan
            df.loc[df['Tobin_Q'].dropna().index, 'Tobin_Q_boxcox'] = boxcox_data
            print(f"✓ Created Tobin_Q_boxcox (λ={lambda_param:.4f})")
    except:
        df['Tobin_Q_boxcox'] = np.nan

# Update dataframes
df_cs = df[df['ConsumerStaples'] == 1].copy()
df_all = df.copy()

# Capture results from analyzer
print("\nCapturing original results from analyzer.results...")

for key, model_info in analyzer.results.items():
    if 'results' in model_info:
        results = model_info['results']

        # Extract model type from key
        if 'quadratic' in key.lower():
            model_type = 'Quadratic'
        elif 'cubic' in key.lower():
            model_type = 'Cubic'
        elif 'interaction' in key.lower():
            model_type = 'Interaction'
        elif 'logarithmic' in key.lower():
            model_type = 'Logarithmic'
        elif 'sqrt' in key.lower() or 'square_root' in key.lower():
            model_type = 'Square Root'
        elif 'threshold' in key.lower():
            model_type = 'Threshold'
        else:
            model_type = 'Other'

        # Store original results
        original_results[key] = {
            'model_type': model_type,
            'r2': results.rsquared,
            'nobs': results.nobs,
            'results': results,
            'data': model_info.get('data', None)
        }

        # Store data sample if available
        if 'data' in model_info and model_info['data'] is not None:
            data_sample = model_info['data'].copy()

            # Add transformation columns to the saved data
            for trans in ['Tobin_Q_log', 'Tobin_Q_sqrt', 'Tobin_Q_inv', 'Tobin_Q_boxcox']:
                if trans in df.columns:
                    data_sample[trans] = df.loc[data_sample.index, trans]

            original_data_samples[key] = data_sample

        print(f"  ✓ {key[:50]}...: R² = {results.rsquared:.6f}, N = {results.nobs}, Type = {model_type}")

print(f"\nCaptured {len(original_results)} original models")
print(f"Captured {len(original_data_samples)} data samples")

# ============================================================================
# ROBUSTNESS CHECK: ALTERNATIVE TRANSFORMATIONS
# ============================================================================
print("\n" + "="*100)
print("ROBUSTNESS CHECK: ALTERNATIVE DEPENDENT VARIABLE TRANSFORMATIONS")
print("="*100)

# Define transformations to test
transformations = [
    ('Original', 'Tobin_Q'),
    ('Log', 'Tobin_Q_log'),
    ('Square Root', 'Tobin_Q_sqrt'),
    ('Inverse', 'Tobin_Q_inv'),
]

if 'Tobin_Q_boxcox' in df.columns and not df['Tobin_Q_boxcox'].isna().all():
    transformations.append(('Box-Cox', 'Tobin_Q_boxcox'))

# Store robustness results
robustness_results = {}
consistency_metrics = []

# Focus on ALL non-linear models (not just cs)
print(f"\nAnalyzing all {len(original_results)} models...")

for model_idx, (model_key, model_info) in enumerate(original_results.items()):
    print(f"\n" + "="*80)
    print(f"MODEL {model_idx+1}/{len(original_results)}: {model_key[:60]}...")
    print("="*80)

    orig_r2 = model_info['r2']
    orig_n = model_info['nobs']
    model_type = model_info['model_type']

    print(f"Model Type: {model_type}")
    print(f"Original R² = {orig_r2:.6f}, N = {orig_n}")

    # Get data sample
    if model_key in original_data_samples:
        data_sample = original_data_samples[model_key].copy()
        print(f"Using saved data sample: {len(data_sample)} observations")
    else:
        # Determine which dataset to use based on key
        if 'Consumer_Staples_Only' in model_key or 'cs' in model_key.lower():
            data_sample = df_cs.copy()
            print(f"Using full Consumer Staples dataset: {len(data_sample)} observations")
        else:
            data_sample = df_all.copy()
            print(f"Using full All Sectors dataset: {len(data_sample)} observations")

    # Get ESG variables from the model (excluding control variables)
    esg_vars = []
    control_vars = []

    for var in model_info['results'].params.index:
        if var == 'const':
            continue
        elif var in ['ROA', 'Size', 'Leverage', 'ConsumerStaples']:
            control_vars.append(var)
        else:
            esg_vars.append(var)

    print(f"ESG variables: {len(esg_vars)}")
    if esg_vars:
        print(f"  First few: {esg_vars[:5]}")
    print(f"Control variables: {control_vars}")

    # Store results for this model
    model_robustness = {}
    trans_results = []

    for trans_name, trans_var in transformations:
        print(f"\n  {trans_name.upper()} TRANSFORMATION:")

        if trans_var not in data_sample.columns:
            print(f"    ✗ {trans_var} not available")
            model_robustness[trans_name] = None
            continue

        # Check if all required variables exist
        required_vars = esg_vars + control_vars + [trans_var]
        available_vars = [v for v in required_vars if v in data_sample.columns]

        if len(available_vars) < len(required_vars):
            missing = set(required_vars) - set(available_vars)
            print(f"    ✗ Missing variables: {missing}")
            model_robustness[trans_name] = None
            continue

        # Drop NA for this transformation
        df_clean = data_sample.dropna(subset=required_vars)

        if len(df_clean) < 10:
            print(f"    ✗ Insufficient data: {len(df_clean)} observations")
            model_robustness[trans_name] = None
            continue

        print(f"    Observations: {len(df_clean)}")

        # Run regression
        y = df_clean[trans_var]
        X = df_clean[esg_vars + control_vars]
        X = pd.concat([pd.Series(1, index=X.index, name='const'), X], axis=1)

        try:
            model = PanelOLS(y, X, entity_effects=False, time_effects=False)
            results = model.fit(cov_type='robust')

            # Calculate key metrics
            r2 = results.rsquared
            r2_diff = r2 - orig_r2

            # Get coefficient signs for key variables
            sign_matches = {}
            sig_matches = {}

            for var in esg_vars:
                if var in results.params and var in model_info['results'].params:
                    orig_coeff = model_info['results'].params[var]
                    new_coeff = results.params[var]
                    orig_pval = model_info['results'].pvalues.get(var, 1.0)
                    new_pval = results.pvalues.get(var, 1.0)

                    orig_sig = orig_pval < 0.10
                    new_sig = new_pval < 0.10

                    sign_match = (np.sign(orig_coeff) == np.sign(new_coeff)) if orig_coeff != 0 else True
                    sig_match = (orig_sig == new_sig)

                    sign_matches[var] = sign_match
                    sig_matches[var] = sig_match

            # Store results
            model_robustness[trans_name] = {
                'r2': r2,
                'r2_diff': r2_diff,
                'nobs': results.nobs,
                'sign_matches': sign_matches,
                'sig_matches': sig_matches,
                'results': results
            }

            # Calculate sign consistency percentage
            if sign_matches:
                sign_consistency = sum(sign_matches.values()) / len(sign_matches) * 100
            else:
                sign_consistency = None

            # Calculate significance consistency percentage
            if sig_matches:
                sig_consistency = sum(sig_matches.values()) / len(sig_matches) * 100
            else:
                sig_consistency = None

            # Print summary
            print(f"    ✓ R² = {r2:.6f} (Δ = {r2_diff:+.6f})")
            if sign_consistency is not None:
                print(f"      Sign consistency: {sign_consistency:.1f}% ({len(sign_matches)} variables)")
            if sig_consistency is not None:
                print(f"      Significance consistency: {sig_consistency:.1f}% ({len(sig_matches)} variables)")

            trans_results.append({
                'trans_name': trans_name,
                'r2': r2,
                'sign_consistency': sign_consistency,
                'sig_consistency': sig_consistency,
                'n_vars': len(sign_matches)
            })

        except Exception as e:
            print(f"    ✗ Failed: {str(e)[:100]}")
            model_robustness[trans_name] = None

    robustness_results[model_key] = model_robustness

    # Calculate overall consistency for this model
    if trans_results:
        print("\n  " + "-" * 40)
        print("  MODEL CONSISTENCY SUMMARY")
        print("  " + "-" * 40)

        # R² stability
        r2_values = [r['r2'] for r in trans_results]
        print(f"  R² range: [{min(r2_values):.6f}, {max(r2_values):.6f}]")
        print(f"  R² stability (max-min): {max(r2_values) - min(r2_values):.6f}")

        # Average sign consistency
        sign_vals = [r['sign_consistency'] for r in trans_results if r['sign_consistency'] is not None]
        if sign_vals:
            avg_sign = np.mean(sign_vals)
            print(f"  Average sign consistency: {avg_sign:.1f}%")
        else:
            avg_sign = None

        # Average significance consistency
        sig_vals = [r['sig_consistency'] for r in trans_results if r['sig_consistency'] is not None]
        if sig_vals:
            avg_sig = np.mean(sig_vals)
            print(f"  Average significance consistency: {avg_sig:.1f}%")
        else:
            avg_sig = None

        # Store metrics
        consistency_metrics.append({
            'model_key': model_key[:50] + '...' if len(model_key) > 50 else model_key,
            'model_type': model_type,
            'original_r2': orig_r2,
            'r2_min': min(r2_values),
            'r2_max': max(r2_values),
            'r2_range': max(r2_values) - min(r2_values),
            'avg_sign_consistency': avg_sign,
            'avg_sig_consistency': avg_sig,
            'n_transformations': len(trans_results)
        })

# ============================================================================
# OVERALL ROBUSTNESS SUMMARY
# ============================================================================
print("\n" + "="*100)
print("OVERALL ROBUSTNESS SUMMARY")
print("="*100)

if consistency_metrics:
    summary_df = pd.DataFrame(consistency_metrics)

    # Reorder columns for better display
    column_order = ['model_key', 'model_type', 'original_r2', 'r2_min', 'r2_max',
                    'r2_range', 'avg_sign_consistency', 'avg_sig_consistency', 'n_transformations']
    summary_df = summary_df[[c for c in column_order if c in summary_df.columns]]

    # Format numeric columns
    for col in ['original_r2', 'r2_min', 'r2_max', 'r2_range']:
        if col in summary_df.columns:
            summary_df[col] = summary_df[col].round(6)

    for col in ['avg_sign_consistency', 'avg_sig_consistency']:
        if col in summary_df.columns:
            summary_df[col] = summary_df[col].round(1)

    print("\n" + "="*120)
    print("ROBUSTNESS SUMMARY TABLE")
    print("="*120)

    # Print a simplified version for display
    display_cols = ['model_type', 'original_r2', 'r2_range', 'avg_sign_consistency', 'avg_sig_consistency']
    display_df = summary_df[display_cols].copy()
    display_df.index = range(1, len(display_df) + 1)
    print(display_df.to_string())

    # Calculate overall metrics
    print("\n" + "="*60)
    print("OVERALL ROBUSTNESS ASSESSMENT")
    print("="*60)

    if 'avg_sign_consistency' in summary_df.columns:
        avg_sign_all = summary_df['avg_sign_consistency'].mean()
        print(f"\nAverage sign consistency across all models: {avg_sign_all:.1f}%")

    if 'avg_sig_consistency' in summary_df.columns:
        avg_sig_all = summary_df['avg_sig_consistency'].mean()
        print(f"Average significance consistency across all models: {avg_sig_all:.1f}%")

    if 'r2_range' in summary_df.columns:
        avg_r2_range = summary_df['r2_range'].mean()
        print(f"Average R² range across transformations: {avg_r2_range:.6f}")

    # Best and worst models
    if 'avg_sign_consistency' in summary_df.columns and len(summary_df) > 0:
        best_idx = summary_df['avg_sign_consistency'].idxmax()
        worst_idx = summary_df['avg_sign_consistency'].idxmin()

        print(f"\nMost robust model (highest sign consistency):")
        print(f"  Type: {summary_df.loc[best_idx, 'model_type']}")
        print(f"  Sign consistency: {summary_df.loc[best_idx, 'avg_sign_consistency']:.1f}%")
        print(f"  R² range: {summary_df.loc[best_idx, 'r2_range']:.6f}")

        print(f"\nLeast robust model (lowest sign consistency):")
        print(f"  Type: {summary_df.loc[worst_idx, 'model_type']}")
        print(f"  Sign consistency: {summary_df.loc[worst_idx, 'avg_sign_consistency']:.1f}%")
        print(f"  R² range: {summary_df.loc[worst_idx, 'r2_range']:.6f}")

    # Overall assessment
    if 'avg_sign_consistency' in summary_df.columns:
        if avg_sign_all >= 80:
            print("\n✅ NON-LINEAR MODELS ARE HIGHLY ROBUST")
            print("   Signs are consistent across transformations (≥80%)")
        elif avg_sign_all >= 60:
            print("\n⚠️ NON-LINEAR MODELS ARE MODERATELY ROBUST")
            print("   Some variation in signs across transformations (60-80%)")
        else:
            print("\n❌ NON-LINEAR MODELS ARE NOT ROBUST")
            print("   Signs vary substantially across transformations (<60%)")

# ============================================================================
# DETAILED RESULTS BY MODEL TYPE
# ============================================================================
print("\n" + "="*100)
print("DETAILED RESULTS BY MODEL TYPE")
print("="*100)

if consistency_metrics and 'model_type' in summary_df.columns:
    model_types = summary_df['model_type'].unique()

    for model_type in sorted(model_types):
        type_df = summary_df[summary_df['model_type'] == model_type]

        print(f"\n{model_type.upper()} MODELS ({len(type_df)} models):")
        print("-" * 50)

        if 'avg_sign_consistency' in type_df.columns:
            sign_mean = type_df['avg_sign_consistency'].mean()
            sign_std = type_df['avg_sign_consistency'].std()
            print(f"  Sign consistency: {sign_mean:.1f}% ± {sign_std:.1f}%")

        if 'avg_sig_consistency' in type_df.columns:
            sig_mean = type_df['avg_sig_consistency'].mean()
            sig_std = type_df['avg_sig_consistency'].std()
            print(f"  Sig consistency: {sig_mean:.1f}% ± {sig_std:.1f}%")

        if 'r2_range' in type_df.columns:
            r2_range_mean = type_df['r2_range'].mean()
            print(f"  Avg R² range: {r2_range_mean:.6f}")

# ============================================================================
# EXPORT ROBUSTNESS RESULTS TO EXCEL
# ============================================================================
print("\n" + "="*100)
print("EXPORTING ROBUSTNESS RESULTS TO EXCEL")
print("="*100)

try:
    timestamp = pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")
    robustness_path = os.path.join(Config.OUTPUT_DIR, f'nonlinear_robustness_{timestamp}.xlsx')

    with pd.ExcelWriter(robustness_path, engine='openpyxl') as writer:
        sheets_created = False

        # Sheet 1: Overall Summary
        if consistency_metrics:
            summary_df.to_excel(writer, sheet_name='Overall_Summary', index=False)
            sheets_created = True

        # Sheet 2: Detailed Results by Model
        detail_data = []
        for model_key, model_robust in robustness_results.items():
            for trans_name, trans_res in model_robust.items():
                if trans_res and isinstance(trans_res, dict):
                    row = {
                        'Model': model_key[:50],
                        'Model_Type': model_info.get('model_type', 'unknown'),
                        'Transformation': trans_name,
                        'R2': trans_res.get('r2'),
                        'R2_Diff': trans_res.get('r2_diff'),
                        'N': trans_res.get('nobs')
                    }

                    # Add sign matches summary
                    sign_matches = trans_res.get('sign_matches', {})
                    if sign_matches:
                        row['Sign_Consistency_%'] = sum(sign_matches.values()) / len(sign_matches) * 100
                        row['N_Vars_Checked'] = len(sign_matches)

                    # Add significance matches summary
                    sig_matches = trans_res.get('sig_matches', {})
                    if sig_matches:
                        row['Sig_Consistency_%'] = sum(sig_matches.values()) / len(sig_matches) * 100

                    detail_data.append(row)

        if detail_data:
            pd.DataFrame(detail_data).to_excel(writer, sheet_name='Detailed_Results', index=False)
            sheets_created = True

        # Sheet 3: Original Models
        orig_data = []
        for key, info in original_results.items():
            row = {
                'Model': key[:50],
                'Type': info.get('model_type', 'unknown'),
                'R2': info['r2'],
                'N': info['nobs']
            }
            orig_data.append(row)

        if orig_data:
            pd.DataFrame(orig_data).to_excel(writer, sheet_name='Original_Models', index=False)
            sheets_created = True

        # If no sheets created, add info
        if not sheets_created:
            pd.DataFrame({
                'Message': ['No robustness results available'],
                'Timestamp': [timestamp]
            }).to_excel(writer, sheet_name='Info', index=False)

    print(f"\n✓ Robustness results exported to: {robustness_path}")

except Exception as e:
    print(f"\n⚠ Could not export to Excel: {str(e)}")
    import traceback
    traceback.print_exc()

print("\n" + "="*100)
print("ROBUSTNESS CHECKS COMPLETE")
print("="*100)
print("\nSummary of findings:")
print("  • Tested transformations: Original, Log, Square Root, Inverse, Box-Cox")
print("  • Compared R² values across transformations")
print("  • Calculated sign consistency for key coefficients")
print("  • Calculated significance consistency (p-value < 0.10)")
if consistency_metrics:
    print(f"  • Analyzed {len(consistency_metrics)} non-linear models")
    print(f"  • Average sign consistency: {summary_df['avg_sign_consistency'].mean():.1f}%")
    print(f"  • Average significance consistency: {summary_df['avg_sig_consistency'].mean():.1f}%")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ================================================================================
# COMPLETE NON-LINEAR EFFECTS ANALYSIS
# With Centered and Simple Approaches
# ================================================================================
#
# ================================================================================
# ANALYSIS 1: CONSUMER STAPLES (Recommended for non-linear effects)
# ================================================================================
#
# ================================================================================
# COMPLETE NON-LINEAR ANALYSIS - CENTERED APPROACH
# Sector: Consumer Staples
# Dependent: Tobin_Q
# ================================================================================
# Loading data and creating all non-linear transformations...
# ------------------------------------------------------------
# Creating lagged ESG variables...
# Creating sector variable...
#
# Creating non-linear transformations...
#
# A. CENTERED TRANSFORMATIONS (Recommended):
# ----------------------------------------
#   ✓ E_lag_centered = E_lag - 72.3449
#   ✓ E_lag_sq_centered = (E_lag_centered)²
#   ✓ E_lag_cube_centered = (E_lag_centered)³
#   ✓ S_lag_centered = S_lag - 74.8235
#   ✓ S_lag_sq_centered = (S_lag_centered)²
#   ✓ S_lag_cube_centered = (S_lag_centered)³
#   ✓ G_lag_centered = G_lag - 73.6079
#   ✓ G_lag_sq_centered = (G_lag_centered)²
#   ✓ G_lag_cube_centered = (G_lag_centered)³
#
# B. SIMPLE TRANSFORMATIONS (for comparison):
# ----------------------------------------
#   ✓ E_lag_sq = (E_lag)²
#   ✓ log_E_lag = ln(E_lag + 0.001)
#   ✓ S_lag_sq = (S_lag)²
#   ✓ log_S_lag = ln(S_lag + 0.001)
#   ✓ G_lag_sq = (G_lag)²
#   ✓ log_G_lag = ln(G_lag + 0.001)
#
# C. THRESHOLD VARIABLES:
# ----------------------------------------
#   ✓ E_lag_above25: 1 if > 59.7225
#   ✓ E_lag_above50: 1 if > 79.3100
#   ✓ E_lag_above75: 1 if > 86.9050
#   ✓ E_lag_above90: 1 if > 92.2730
#   ✓ S_lag_above25: 1 if > 65.6275
#   ✓ S_lag_above50: 1 if > 77.9900
#   ✓ S_lag_above75: 1 if > 88.2575
#   ✓ S_lag_above90: 1 if > 93.4130
#   ✓ G_lag_above25: 1 if > 62.6725
#   ✓ G_lag_above50: 1 if > 77.1850
#   ✓ G_lag_above75: 1 if > 86.3275
#   ✓ G_lag_above90: 1 if > 92.3730
#
# D. INTERACTION TERMS (centered):
# ----------------------------------------
#   ✓ E_lag_centered_S_lag_centered_interact = E_lag_centered × S_lag_centered
#   ✓ E_lag_centered_G_lag_centered_interact = E_lag_centered × G_lag_centered
#   ✓ S_lag_centered_G_lag_centered_interact = S_lag_centered × G_lag_centered
#
# ✓ Created 33 non-linear transformations
#
# ============================================================
# DATA PREPARATION COMPLETE
# ============================================================
# Total observations: 388
# Consumer Staples: 80
# Other sectors: 308
#
# ESG means (for centering):
#   E_lag: 72.3449
#   S_lag: 74.8235
#   G_lag: 73.6079
#
# Running model specifications (CENTERED approach)...
#
# 1. QUADRATIC MODEL:
#   N = 72, Variables = 6
#   Max VIF = 12.82
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.489903, Adj. R² = 0.489903
#   Key coefficients:
#     E_lag_centered: 0.013639**
#     E_lag_sq_centered: -0.000597
#     S_lag_centered: 0.015993**
#   Turning points:
#     E: Inverted U-shaped (concave) at 91.6340
#     S: U-shaped (convex) at 72.0178
#     G: Inverted U-shaped (concave) at 62.2888
#
# 2. CUBIC MODEL:
#   N = 72, Variables = 9
#   Max VIF = 140.56
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.555214, Adj. R² = 0.555214
#   Key coefficients:
#     E_lag_centered: 0.048766***
#     E_lag_sq_centered: -0.000321
#     E_lag_cube_centered: -0.000107***
#   Turning points:
#   ✗ Error: 'shape'
#
# 3. LOGARITHMIC MODEL:
#   N = 72, Variables = 3
#   Max VIF = 454.18
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.420355, Adj. R² = 0.420355
#   Key coefficients:
#     log_E_lag: 1.023543**
#     log_S_lag: 0.406631
#     log_G_lag: -0.684159**
#
# 4. SQUARE ROOT MODEL:
#   N = 72, Variables = 3
#   Max VIF = 208.44
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.434960, Adj. R² = 0.434960
#   Key coefficients:
#     sqrt_E_lag: 0.179257
#     sqrt_S_lag: 0.200841*
#     sqrt_G_lag: -0.172923**
#
# 5. THRESHOLD MODELS:
#   ✓ S_lag > 92.42: β = 0.3181 (p=0.018)
#
# 6. INTERACTION MODEL:
#   N = 72, R² = 0.502307
#   E: Marginal effect = 0.014944
#   S: Marginal effect = 0.018180
#   G: Marginal effect = -0.009810
#
# 7. MODEL COMPARISON:
#
# Model                Approach        N           R²      Adj. R²    Max VIF          AIC          BIC
# --------------------------------------------------------------------------------------------------------------
# Interaction          Centered       72     0.502307     0.502307        nan        -85.0        -62.2
# Quadratic            Centered       72     0.489903     0.489903      12.82        -83.2        -60.4
# Square Root          Centered       72     0.434960     0.434960     208.44        -81.8        -65.9
# Logarithmic          Centered       72     0.420355     0.420355     454.18        -80.0        -64.1
#
# 8. BEST MODEL SELECTION:
#
# Best by R²: interaction (R² = 0.502307)
# Best by BIC: sqrt (BIC = -65.9)
# Best by VIF: quadratic (VIF = 12.82)
#
# RECOMMENDED MODEL: SQRT
#   • R² = 0.434960
#   • BIC = -65.9
#   • Max VIF = 208.44
#   • Approach: Centered
#
# 9. MODEL DIAGNOSTICS (Best Model):
#
# 1. Multicollinearity (VIF):
#    Max VIF: 208.44
#    High VIF variables: ['sqrt_E_lag', 'sqrt_S_lag', 'sqrt_G_lag']
#
# 2. Functional Form (RESET test):
#    Could not perform RESET test: result must come from a linear regression model
#
# 3. Heteroskedasticity (Breusch-Pagan):
#    LM statistic: 6.7075
#    p-value: 0.3487
#    ✓ No evidence of heteroskedasticity
#
# 4. Normality of Residuals:
#    Jarque-Bera: 2.9708 (p=0.2264)
#    ✓ Cannot reject normality
#
# 10. FINAL SUMMARY:
#
# ================================================================================
# FINAL ANALYSIS SUMMARY
# ================================================================================
#
# Analysis Details:
#   • Sector: Consumer Staples Only
#   • Dependent variable: Tobin_Q
#   • Approach: Centered (recommended)
#   • Models tested: 5
#
# Best Model: SQUARE_ROOT
#   • R²: 0.434960
#   • Adjusted R²: 0.434960
#   • Observations: 72
#   • Max VIF: 208.44
#
# ✓ All results saved to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/nonlinear_complete_outputs/nonlinear_results_Consumer_Staples_Only_Tobin_Q.xlsx
#
# ================================================================================
# ANALYSIS 2: ALL SECTORS (Comparison)
# ================================================================================
#
# ================================================================================
# COMPLETE NON-LINEAR ANALYSIS - CENTERED APPROACH
# Sector: All Sectors
# Dependent: Tobin_Q
# ================================================================================
# Loading data and creating all non-linear transformations...
# ------------------------------------------------------------
# Creating lagged ESG variables...
# Creating sector variable...
#
# Creating non-linear transformations...
#
# A. CENTERED TRANSFORMATIONS (Recommended):
# ----------------------------------------
#   ✓ E_lag_centered = E_lag - 72.3449
#   ✓ E_lag_sq_centered = (E_lag_centered)²
#   ✓ E_lag_cube_centered = (E_lag_centered)³
#   ✓ S_lag_centered = S_lag - 74.8235
#   ✓ S_lag_sq_centered = (S_lag_centered)²
#   ✓ S_lag_cube_centered = (S_lag_centered)³
#   ✓ G_lag_centered = G_lag - 73.6079
#   ✓ G_lag_sq_centered = (G_lag_centered)²
#   ✓ G_lag_cube_centered = (G_lag_centered)³
#
# B. SIMPLE TRANSFORMATIONS (for comparison):
# ----------------------------------------
#   ✓ E_lag_sq = (E_lag)²
#   ✓ log_E_lag = ln(E_lag + 0.001)
#   ✓ S_lag_sq = (S_lag)²
#   ✓ log_S_lag = ln(S_lag + 0.001)
#   ✓ G_lag_sq = (G_lag)²
#   ✓ log_G_lag = ln(G_lag + 0.001)
#
# C. THRESHOLD VARIABLES:
# ----------------------------------------
#   ✓ E_lag_above25: 1 if > 59.7225
#   ✓ E_lag_above50: 1 if > 79.3100
#   ✓ E_lag_above75: 1 if > 86.9050
#   ✓ E_lag_above90: 1 if > 92.2730
#   ✓ S_lag_above25: 1 if > 65.6275
#   ✓ S_lag_above50: 1 if > 77.9900
#   ✓ S_lag_above75: 1 if > 88.2575
#   ✓ S_lag_above90: 1 if > 93.4130
#   ✓ G_lag_above25: 1 if > 62.6725
#   ✓ G_lag_above50: 1 if > 77.1850
#   ✓ G_lag_above75: 1 if > 86.3275
#   ✓ G_lag_above90: 1 if > 92.3730
#
# D. INTERACTION TERMS (centered):
# ----------------------------------------
#   ✓ E_lag_centered_S_lag_centered_interact = E_lag_centered × S_lag_centered
#   ✓ E_lag_centered_G_lag_centered_interact = E_lag_centered × G_lag_centered
#   ✓ S_lag_centered_G_lag_centered_interact = S_lag_centered × G_lag_centered
#
# ✓ Created 33 non-linear transformations
#
# ============================================================
# DATA PREPARATION COMPLETE
# ============================================================
# Total observations: 388
# Consumer Staples: 80
# Other sectors: 308
#
# ESG means (for centering):
#   E_lag: 72.3449
#   S_lag: 74.8235
#   G_lag: 73.6079
#
# Running model specifications (CENTERED approach)...
#
# 1. QUADRATIC MODEL:
#   N = 348, Variables = 6
#   Max VIF = 2.80
#   R² = 0.496351, Adj. R² = 0.496351
#   Key coefficients:
#     E_lag_centered: 0.000013
#     E_lag_sq_centered: 0.000300**
#     S_lag_centered: 0.014893***
#   Turning points:
#     E: U-shaped (convex) at 72.3241
#     S: Inverted U-shaped (concave) at 119.3554
#     G: U-shaped (convex) at 70.6907
#
# 2. CUBIC MODEL:
#   N = 348, Variables = 9
#   Max VIF = 11.34
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.511538, Adj. R² = 0.511538
#   Key coefficients:
#     E_lag_centered: -0.004483
#     E_lag_sq_centered: 0.000644***
#     E_lag_cube_centered: 0.000010*
#   Turning points:
#   ✗ Error: 'shape'
#
# 3. LOGARITHMIC MODEL:
#   N = 348, Variables = 3
#   Max VIF = 397.50
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.477857, Adj. R² = 0.477857
#   Key coefficients:
#     log_E_lag: -0.299543
#     log_S_lag: 0.825531***
#     log_G_lag: -0.076679
#
# 4. SQUARE ROOT MODEL:
#   N = 348, Variables = 3
#   Max VIF = 118.68
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.483014, Adj. R² = 0.483014
#   Key coefficients:
#     sqrt_E_lag: -0.085000*
#     sqrt_S_lag: 0.244858***
#     sqrt_G_lag: -0.008094
#
# 5. THRESHOLD MODELS:
#   ✓ E_lag > 86.91: β = 0.1614 (p=0.022)
#   ✓ E_lag > 92.27: β = 0.2529 (p=0.007)
#   ✓ S_lag > 65.63: β = 0.1649 (p=0.024)
#   ✓ S_lag > 77.99: β = 0.1993 (p=0.001)
#   ✓ S_lag > 88.26: β = 0.2288 (p=0.001)
#   ✓ S_lag > 93.41: β = 0.3799 (p=0.000)
#   ✓ G_lag > 86.33: β = 0.1283 (p=0.063)
#
# 6. INTERACTION MODEL:
#   N = 348, R² = 0.507337
#   E: Marginal effect = -0.001467
#   S: Marginal effect = 0.012941
#   G: Marginal effect = 0.000074
#
# 7. MODEL COMPARISON:
#
# Model                Approach        N           R²      Adj. R²    Max VIF          AIC          BIC
# --------------------------------------------------------------------------------------------------------------
# Interaction          Centered      348     0.507337     0.507337        nan       -357.5       -315.2
# Quadratic            Centered      348     0.496351     0.496351       2.80       -349.9       -307.5
# Square Root          Centered      348     0.483014     0.483014     118.68       -346.8       -315.9
# Logarithmic          Centered      348     0.477857     0.477857     397.50       -343.3       -312.5
#
# 8. BEST MODEL SELECTION:
#
# Best by R²: interaction (R² = 0.507337)
# Best by BIC: sqrt (BIC = -315.9)
# Best by VIF: quadratic (VIF = 2.80)
#
# RECOMMENDED MODEL: SQRT
#   • R² = 0.483014
#   • BIC = -315.9
#   • Max VIF = 118.68
#   • Approach: Centered
#
# 10. FINAL SUMMARY:
#
# ================================================================================
# FINAL ANALYSIS SUMMARY
# ================================================================================
#
# Analysis Details:
#   • Sector: All Sectors
#   • Dependent variable: Tobin_Q
#   • Approach: Centered (recommended)
#   • Models tested: 5
#
# Best Model: SQUARE_ROOT
#   • R²: 0.483014
#   • Adjusted R²: 0.483014
#   • Observations: 348
#   • Max VIF: 118.68
#
# ✓ All results saved to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/nonlinear_complete_outputs/nonlinear_results_All_Sectors_Tobin_Q.xlsx
#
# ================================================================================
# ANALYSIS 3: LOG-TRANSFORMED TOBIN'S Q (Robustness)
# ================================================================================
#
# ================================================================================
# COMPLETE NON-LINEAR ANALYSIS - CENTERED APPROACH
# Sector: Consumer Staples
# Dependent: Tobin_Q_log
# ================================================================================
# Loading data and creating all non-linear transformations...
# ------------------------------------------------------------
# Creating lagged ESG variables...
# Creating sector variable...
#
# Creating non-linear transformations...
#
# A. CENTERED TRANSFORMATIONS (Recommended):
# ----------------------------------------
#   ✓ E_lag_centered = E_lag - 72.3449
#   ✓ E_lag_sq_centered = (E_lag_centered)²
#   ✓ E_lag_cube_centered = (E_lag_centered)³
#   ✓ S_lag_centered = S_lag - 74.8235
#   ✓ S_lag_sq_centered = (S_lag_centered)²
#   ✓ S_lag_cube_centered = (S_lag_centered)³
#   ✓ G_lag_centered = G_lag - 73.6079
#   ✓ G_lag_sq_centered = (G_lag_centered)²
#   ✓ G_lag_cube_centered = (G_lag_centered)³
#
# B. SIMPLE TRANSFORMATIONS (for comparison):
# ----------------------------------------
#   ✓ E_lag_sq = (E_lag)²
#   ✓ log_E_lag = ln(E_lag + 0.001)
#   ✓ S_lag_sq = (S_lag)²
#   ✓ log_S_lag = ln(S_lag + 0.001)
#   ✓ G_lag_sq = (G_lag)²
#   ✓ log_G_lag = ln(G_lag + 0.001)
#
# C. THRESHOLD VARIABLES:
# ----------------------------------------
#   ✓ E_lag_above25: 1 if > 59.7225
#   ✓ E_lag_above50: 1 if > 79.3100
#   ✓ E_lag_above75: 1 if > 86.9050
#   ✓ E_lag_above90: 1 if > 92.2730
#   ✓ S_lag_above25: 1 if > 65.6275
#   ✓ S_lag_above50: 1 if > 77.9900
#   ✓ S_lag_above75: 1 if > 88.2575
#   ✓ S_lag_above90: 1 if > 93.4130
#   ✓ G_lag_above25: 1 if > 62.6725
#   ✓ G_lag_above50: 1 if > 77.1850
#   ✓ G_lag_above75: 1 if > 86.3275
#   ✓ G_lag_above90: 1 if > 92.3730
#
# D. INTERACTION TERMS (centered):
# ----------------------------------------
#   ✓ E_lag_centered_S_lag_centered_interact = E_lag_centered × S_lag_centered
#   ✓ E_lag_centered_G_lag_centered_interact = E_lag_centered × G_lag_centered
#   ✓ S_lag_centered_G_lag_centered_interact = S_lag_centered × G_lag_centered
#
# ✓ Created 33 non-linear transformations
#
# ============================================================
# DATA PREPARATION COMPLETE
# ============================================================
# Total observations: 388
# Consumer Staples: 80
# Other sectors: 308
#
# ESG means (for centering):
#   E_lag: 72.3449
#   S_lag: 74.8235
#   G_lag: 73.6079
#
# Running model specifications (CENTERED approach)...
#
# 1. QUADRATIC MODEL:
#   N = 72, Variables = 6
#   Max VIF = 12.82
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.568085, Adj. R² = 0.568085
#   Key coefficients:
#     E_lag_centered: 0.008640**
#     E_lag_sq_centered: -0.000435
#     S_lag_centered: 0.010135**
#   Turning points:
#     E: Inverted U-shaped (concave) at 90.1556
#     S: U-shaped (convex) at 71.2403
#     G: Inverted U-shaped (concave) at 59.5266
#
# 2. CUBIC MODEL:
#   N = 72, Variables = 9
#   Max VIF = 140.56
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.639908, Adj. R² = 0.639908
#   Key coefficients:
#     E_lag_centered: 0.030589***
#     E_lag_sq_centered: -0.000275
#     E_lag_cube_centered: -0.000067***
#   Turning points:
#   ✗ Error: 'shape'
#
# 3. LOGARITHMIC MODEL:
#   N = 72, Variables = 3
#   Max VIF = 454.18
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.481671, Adj. R² = 0.481671
#   Key coefficients:
#     log_E_lag: 0.677185**
#     log_S_lag: 0.238670
#     log_G_lag: -0.387122**
#
# 4. SQUARE ROOT MODEL:
#   N = 72, Variables = 3
#   Max VIF = 208.44
#   ⚠ High multicollinearity (VIF > 10)
#   R² = 0.500720, Adj. R² = 0.500720
#   Key coefficients:
#     sqrt_E_lag: 0.115003
#     sqrt_S_lag: 0.128937*
#     sqrt_G_lag: -0.098160**
#
# 5. THRESHOLD MODELS:
#   ✓ E_lag > 83.99: β = 0.1792 (p=0.083)
#   ✓ S_lag > 88.34: β = 0.2348 (p=0.024)
#   ✓ S_lag > 92.42: β = 0.2199 (p=0.003)
#   ✓ S_lag > 94.17: β = 0.1729 (p=0.088)
#
# 6. INTERACTION MODEL:
#   N = 72, R² = 0.563083
#   E: Marginal effect = 0.008276
#   S: Marginal effect = 0.012956
#   G: Marginal effect = -0.005608
#
# 7. MODEL COMPARISON:
#
# Model                Approach        N           R²      Adj. R²    Max VIF          AIC          BIC
# --------------------------------------------------------------------------------------------------------------
# Quadratic            Centered       72     0.568085     0.568085      12.82       -171.7       -148.9
# Interaction          Centered       72     0.563083     0.563083        nan       -170.9       -148.1
# Square Root          Centered       72     0.500720     0.500720     208.44       -167.3       -151.3
# Logarithmic          Centered       72     0.481671     0.481671     454.18       -164.6       -148.6
#
# 8. BEST MODEL SELECTION:
#
# Best by R²: quadratic (R² = 0.568085)
# Best by BIC: sqrt (BIC = -151.3)
# Best by VIF: quadratic (VIF = 12.82)
#
# RECOMMENDED MODEL: SQRT
#   • R² = 0.500720
#   • BIC = -151.3
#   • Max VIF = 208.44
#   • Approach: Centered
#
# 10. FINAL SUMMARY:
#
# ================================================================================
# FINAL ANALYSIS SUMMARY
# ================================================================================
#
# Analysis Details:
#   • Sector: Consumer Staples Only
#   • Dependent variable: Tobin_Q_log
#   • Approach: Centered (recommended)
#   • Models tested: 5
#
# Best Model: SQUARE_ROOT
#   • R²: 0.500720
#   • Adjusted R²: 0.500720
#   • Observations: 72
#   • Max VIF: 208.44
#
# ✓ All results saved to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/nonlinear_complete_outputs/nonlinear_results_Consumer_Staples_Only_Tobin_Q_log.xlsx
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================
#
# Summary:
#   • Output directory: /content/drive/MyDrive/Colab Notebooks/FTSE Data/nonlinear_complete_outputs
#   • Approach used: CENTERED (recommended)
#   • Models run: 9
#   • Files saved: Check /content/drive/MyDrive/Colab Notebooks/FTSE Data/nonlinear_complete_outputs
#
# ====================================================================================================
# ROBUSTNESS CHECKS FOR NON-LINEAR MODELS
# ====================================================================================================
# Testing sensitivity to dependent variable transformations
# Using EXACT same data samples as main program for each model
#
# ------------------------------------------------------------
# ORIGINAL MODEL RESULTS (FROM MAIN PROGRAM)
# ------------------------------------------------------------
#
# Available transformations in data:
#   ✓ Tobin_Q_log
#   ✗ Tobin_Q_sqrt
#   ✗ Tobin_Q_inv
#   ✗ Tobin_Q_boxcox
# ✓ Created Tobin_Q_sqrt
# ✓ Created Tobin_Q_inv
# ✓ Created Tobin_Q_boxcox (λ=-0.9814)
#
# Capturing original results from analyzer.results...
#   ✓ quadratic_centered_Consumer_Staples_Only_Tobin_Q...: R² = 0.489903, N = 72, Type = Quadratic
#   ✓ logarithmic_centered_Consumer_Staples_Only_Tobin_Q...: R² = 0.420355, N = 72, Type = Logarithmic
#   ✓ square_root_centered_Consumer_Staples_Only_Tobin_Q...: R² = 0.434960, N = 72, Type = Square Root
#   ✓ quadratic_centered_All_Sectors_Tobin_Q...: R² = 0.496351, N = 348, Type = Quadratic
#   ✓ logarithmic_centered_All_Sectors_Tobin_Q...: R² = 0.477857, N = 348, Type = Logarithmic
#   ✓ square_root_centered_All_Sectors_Tobin_Q...: R² = 0.483014, N = 348, Type = Square Root
#   ✓ quadratic_centered_Consumer_Staples_Only_Tobin_Q_l...: R² = 0.568085, N = 72, Type = Quadratic
#   ✓ logarithmic_centered_Consumer_Staples_Only_Tobin_Q...: R² = 0.481671, N = 72, Type = Logarithmic
#   ✓ square_root_centered_Consumer_Staples_Only_Tobin_Q...: R² = 0.500720, N = 72, Type = Square Root
#
# Captured 9 original models
# Captured 9 data samples
#
# ====================================================================================================
# ROBUSTNESS CHECK: ALTERNATIVE DEPENDENT VARIABLE TRANSFORMATIONS
# ====================================================================================================
#
# Analyzing all 9 models...
#
# ================================================================================
# MODEL 1/9: quadratic_centered_Consumer_Staples_Only_Tobin_Q...
# ================================================================================
# Model Type: Quadratic
# Original R² = 0.489903, N = 72
# Using saved data sample: 72 observations
# ESG variables: 6
#   First few: ['E_lag_centered', 'E_lag_sq_centered', 'S_lag_centered', 'S_lag_sq_centered', 'G_lag_centered']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.489903 (Δ = +0.000000)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.568085 (Δ = +0.078182)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.530403 (Δ = +0.040500)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.629831 (Δ = +0.139928)
#       Sign consistency: 0.0% (6 variables)
#       Significance consistency: 83.3% (6 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.628811 (Δ = +0.138908)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 83.3% (6 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.489903, 0.629831]
#   R² stability (max-min): 0.139928
#   Average sign consistency: 80.0%
#   Average significance consistency: 93.3%
#
# ================================================================================
# MODEL 2/9: logarithmic_centered_Consumer_Staples_Only_Tobin_Q...
# ================================================================================
# Model Type: Logarithmic
# Original R² = 0.420355, N = 72
# Using saved data sample: 72 observations
# ESG variables: 3
#   First few: ['log_E_lag', 'log_S_lag', 'log_G_lag']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.420355 (Δ = +0.000000)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.481671 (Δ = +0.061316)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.452596 (Δ = +0.032241)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.526193 (Δ = +0.105839)
#       Sign consistency: 0.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.525509 (Δ = +0.105154)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.420355, 0.526193]
#   R² stability (max-min): 0.105839
#   Average sign consistency: 80.0%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 3/9: square_root_centered_Consumer_Staples_Only_Tobin_Q...
# ================================================================================
# Model Type: Square Root
# Original R² = 0.434960, N = 72
# Using saved data sample: 72 observations
# ESG variables: 3
#   First few: ['sqrt_E_lag', 'sqrt_S_lag', 'sqrt_G_lag']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.434960 (Δ = +0.000000)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.500720 (Δ = +0.065760)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.469360 (Δ = +0.034401)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.550008 (Δ = +0.115049)
#       Sign consistency: 0.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.549228 (Δ = +0.114268)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.434960, 0.550008]
#   R² stability (max-min): 0.115049
#   Average sign consistency: 80.0%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 4/9: quadratic_centered_All_Sectors_Tobin_Q...
# ================================================================================
# Model Type: Quadratic
# Original R² = 0.496351, N = 348
# Using saved data sample: 348 observations
# ESG variables: 6
#   First few: ['E_lag_centered', 'E_lag_sq_centered', 'S_lag_centered', 'S_lag_sq_centered', 'G_lag_centered']
# Control variables: ['ROA', 'Size', 'Leverage', 'ConsumerStaples']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.496351 (Δ = +0.000000)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.579983 (Δ = +0.083632)
#       Sign consistency: 83.3% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.542868 (Δ = +0.046518)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.619011 (Δ = +0.122660)
#       Sign consistency: 16.7% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.618712 (Δ = +0.122362)
#       Sign consistency: 83.3% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.496351, 0.619011]
#   R² stability (max-min): 0.122660
#   Average sign consistency: 76.7%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 5/9: logarithmic_centered_All_Sectors_Tobin_Q...
# ================================================================================
# Model Type: Logarithmic
# Original R² = 0.477857, N = 348
# Using saved data sample: 348 observations
# ESG variables: 3
#   First few: ['log_E_lag', 'log_S_lag', 'log_G_lag']
# Control variables: ['ROA', 'Size', 'Leverage', 'ConsumerStaples']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.477857 (Δ = +0.000000)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.559262 (Δ = +0.081404)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.523256 (Δ = +0.045399)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.597056 (Δ = +0.119199)
#       Sign consistency: 0.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.596762 (Δ = +0.118905)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.477857, 0.597056]
#   R² stability (max-min): 0.119199
#   Average sign consistency: 80.0%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 6/9: square_root_centered_All_Sectors_Tobin_Q...
# ================================================================================
# Model Type: Square Root
# Original R² = 0.483014, N = 348
# Using saved data sample: 348 observations
# ESG variables: 3
#   First few: ['sqrt_E_lag', 'sqrt_S_lag', 'sqrt_G_lag']
# Control variables: ['ROA', 'Size', 'Leverage', 'ConsumerStaples']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.483014 (Δ = +0.000000)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.567868 (Δ = +0.084855)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.530267 (Δ = +0.047254)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.607459 (Δ = +0.124446)
#       Sign consistency: 0.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 348
#     ✓ R² = 0.607151 (Δ = +0.124137)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.483014, 0.607459]
#   R² stability (max-min): 0.124446
#   Average sign consistency: 80.0%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 7/9: quadratic_centered_Consumer_Staples_Only_Tobin_Q_log...
# ================================================================================
# Model Type: Quadratic
# Original R² = 0.568085, N = 72
# Using saved data sample: 72 observations
# ESG variables: 6
#   First few: ['E_lag_centered', 'E_lag_sq_centered', 'S_lag_centered', 'S_lag_sq_centered', 'G_lag_centered']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.489903 (Δ = -0.078182)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.568085 (Δ = +0.000000)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.530403 (Δ = -0.037682)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 100.0% (6 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.629831 (Δ = +0.061746)
#       Sign consistency: 0.0% (6 variables)
#       Significance consistency: 83.3% (6 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.628811 (Δ = +0.060726)
#       Sign consistency: 100.0% (6 variables)
#       Significance consistency: 83.3% (6 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.489903, 0.629831]
#   R² stability (max-min): 0.139928
#   Average sign consistency: 80.0%
#   Average significance consistency: 93.3%
#
# ================================================================================
# MODEL 8/9: logarithmic_centered_Consumer_Staples_Only_Tobin_Q_log...
# ================================================================================
# Model Type: Logarithmic
# Original R² = 0.481671, N = 72
# Using saved data sample: 72 observations
# ESG variables: 3
#   First few: ['log_E_lag', 'log_S_lag', 'log_G_lag']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.420355 (Δ = -0.061316)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.481671 (Δ = +0.000000)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.452596 (Δ = -0.029075)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.526193 (Δ = +0.044523)
#       Sign consistency: 0.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.525509 (Δ = +0.043838)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.420355, 0.526193]
#   R² stability (max-min): 0.105839
#   Average sign consistency: 80.0%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 9/9: square_root_centered_Consumer_Staples_Only_Tobin_Q_log...
# ================================================================================
# Model Type: Square Root
# Original R² = 0.500720, N = 72
# Using saved data sample: 72 observations
# ESG variables: 3
#   First few: ['sqrt_E_lag', 'sqrt_S_lag', 'sqrt_G_lag']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.434960 (Δ = -0.065760)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   LOG TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.500720 (Δ = +0.000000)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.469360 (Δ = -0.031360)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   INVERSE TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.550008 (Δ = +0.049288)
#       Sign consistency: 0.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   BOX-COX TRANSFORMATION:
#     Observations: 72
#     ✓ R² = 0.549228 (Δ = +0.048508)
#       Sign consistency: 100.0% (3 variables)
#       Significance consistency: 100.0% (3 variables)
#
#   ----------------------------------------
#   MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.434960, 0.550008]
#   R² stability (max-min): 0.115049
#   Average sign consistency: 80.0%
#   Average significance consistency: 100.0%
#
# ====================================================================================================
# OVERALL ROBUSTNESS SUMMARY
# ====================================================================================================
#
# ========================================================================================================================
# ROBUSTNESS SUMMARY TABLE
# ========================================================================================================================
#     model_type  original_r2  r2_range  avg_sign_consistency  avg_sig_consistency
# 1    Quadratic     0.489903  0.139928                  80.0                 93.3
# 2  Logarithmic     0.420355  0.105839                  80.0                100.0
# 3  Square Root     0.434960  0.115049                  80.0                100.0
# 4    Quadratic     0.496351  0.122660                  76.7                100.0
# 5  Logarithmic     0.477857  0.119199                  80.0                100.0
# 6  Square Root     0.483014  0.124446                  80.0                100.0
# 7    Quadratic     0.568085  0.139928                  80.0                 93.3
# 8  Logarithmic     0.481671  0.105839                  80.0                100.0
# 9  Square Root     0.500720  0.115049                  80.0                100.0
#
# ============================================================
# OVERALL ROBUSTNESS ASSESSMENT
# ============================================================
#
# Average sign consistency across all models: 79.6%
# Average significance consistency across all models: 98.5%
# Average R² range across transformations: 0.120882
#
# Most robust model (highest sign consistency):
#   Type: Quadratic
#   Sign consistency: 80.0%
#   R² range: 0.139928
#
# Least robust model (lowest sign consistency):
#   Type: Quadratic
#   Sign consistency: 76.7%
#   R² range: 0.122660
#
# ⚠️ NON-LINEAR MODELS ARE MODERATELY ROBUST
#    Some variation in signs across transformations (60-80%)
#
# ====================================================================================================
# DETAILED RESULTS BY MODEL TYPE
# ====================================================================================================
#
# LOGARITHMIC MODELS (3 models):
# --------------------------------------------------
#   Sign consistency: 80.0% ± 0.0%
#   Sig consistency: 100.0% ± 0.0%
#   Avg R² range: 0.110292
#
# QUADRATIC MODELS (3 models):
# --------------------------------------------------
#   Sign consistency: 78.9% ± 1.9%
#   Sig consistency: 95.5% ± 3.9%
#   Avg R² range: 0.134172
#
# SQUARE ROOT MODELS (3 models):
# --------------------------------------------------
#   Sign consistency: 80.0% ± 0.0%
#   Sig consistency: 100.0% ± 0.0%
#   Avg R² range: 0.118181
#
# ====================================================================================================
# EXPORTING ROBUSTNESS RESULTS TO EXCEL
# ====================================================================================================
#
# ✓ Robustness results exported to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/nonlinear_complete_outputs/nonlinear_robustness_20260215_163435.xlsx
#
# ====================================================================================================
# ROBUSTNESS CHECKS COMPLETE
# ====================================================================================================
#
# Summary of findings:
#   • Tested transformations: Original, Log, Square Root, Inverse, Box-Cox
#   • Compared R² values across transformations
#   • Calculated sign consistency for key coefficients
#   • Calculated significance consistency (p-value < 0.10)
#   • Analyzed 9 non-linear models
#   • Average sign consistency: 79.6%
#   • Average significance consistency: 98.5%
