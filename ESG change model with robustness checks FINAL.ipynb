# %% [markdown]
# <a href="https://colab.research.google.com/github/mmuputisi/Adv-Py_Data_Analysis/blob/main/ESG%20change%20model%20with%20robustness%20checks%20FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# esg_change_model.py
"""
Standalone program for ESG-Tobin's Q analysis using Change in Lagged ESG models.
Properly aligned with t-1 ESG scores vs t financial performance.
"""

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from linearmodels.panel import PanelOLS
import warnings
warnings.filterwarnings('ignore')

class ChangeESGAnalysis:
    """
    Standalone class for running Change in Lagged ESG models on Tobin's Q.
    Properly aligned: ESG changes from t-2 to t-1 predict Tobin's Q at t.
    """

    def __init__(self, data_path, output_dir):
        """
        Initialize the Change in ESG analysis.

        Parameters:
        -----------
        data_path : str
            Path to the Excel data file
        output_dir : str
            Directory to save output files
        """
        self.data_path = data_path
        self.output_dir = output_dir
        self.df = None
        self.change_data = {}
        self.results = {}
        self.results_summary = []  # For tabular export

        # Create output directory if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)

        # Setup plotting style
        plt.style.use('seaborn-v0_8-whitegrid')
        sns.set_palette("husl")

    def load_and_prepare_data(self):
        """
        Load data and prepare basic transformations.
        """
        print("=" * 70)
        print("LOADING AND PREPARING DATA FOR CHANGE IN ESG ANALYSIS")
        print("=" * 70)

        try:
            # Load data
            self.df = pd.read_excel(self.data_path)
            print(f"✓ Loaded data from: {self.data_path}")

            # Set multi-index
            if 'Firm' in self.df.columns and 'Year' in self.df.columns:
                self.df = self.df.set_index(['Firm', 'Year']).sort_index()
                print("✓ Set multi-index (Firm, Year)")
            else:
                print("⚠ Warning: 'Firm' and/or 'Year' columns not found")
                print(f"  Available columns: {list(self.df.columns)}")
                self.df = self.df.set_index([self.df.columns[0], self.df.columns[1]]).sort_index()
                print(f"  Using {self.df.index.names} as index")

            # Rename columns if needed
            column_renames = {}
            if "Tobin's Q" in self.df.columns:
                column_renames["Tobin's Q"] = "Tobin_Q"

            if column_renames:
                self.df = self.df.rename(columns=column_renames)
                print(f"✓ Renamed columns: {column_renames}")

            # Create basic control variables
            if 'Total Assets' in self.df.columns:
                self.df['Size'] = np.log(self.df['Total Assets'].replace(0, np.nan))
                print("✓ Created Size variable (log of Total Assets)")
            else:
                print("⚠ Warning: 'Total Assets' column not found")

            if 'Total Liabilities' in self.df.columns and 'Total Assets' in self.df.columns:
                self.df['Leverage'] = self.df['Total Liabilities'] / self.df['Total Assets'].replace(0, np.nan)
                print("✓ Created Leverage variable")
            else:
                print("⚠ Warning: Could not create Leverage variable")

            # Check for ESG columns
            esg_columns = [col for col in ['E', 'S', 'G'] if col in self.df.columns]
            if len(esg_columns) == 3:
                print(f"✓ Found ESG columns: {esg_columns}")
            else:
                print(f"⚠ Missing ESG columns. Found: {esg_columns}")

            print(f"\n✓ Loaded {len(self.df)} observations")
            print(f"✓ Number of firms: {self.df.index.get_level_values(0).nunique()}")
            print(f"✓ Years: {sorted(self.df.index.get_level_values(1).unique())}")

            return self.df

        except Exception as e:
            print(f"✗ Error loading data: {e}")
            import traceback
            traceback.print_exc()
            return None

    def create_sector_variable(self):
        """
        Create Consumer Staples sector variable.
        """
        print("\n" + "-" * 50)
        print("CREATING SECTOR VARIABLES")
        print("-" * 50)

        # Define Consumer Staples firms
        consumer_staples_firms = [
            'Associated British Foods', 'British American Tobacco', 'Coca Cola HBC AG',
            'Diageo', 'J. Sainsbury', 'Reckitt Benckiser', 'Tesco', 'Unilever', 'Haleon Plc'
        ]

        # Get unique firm names
        firm_names = self.df.index.get_level_values(0).unique()
        print(f"Found {len(firm_names)} unique firms")

        # Check which Consumer Staples firms are in the data
        found_cs_firms = [firm for firm in consumer_staples_firms if firm in firm_names]
        print(f"Found {len(found_cs_firms)} Consumer Staples firms in data: {found_cs_firms}")

        # Create sector variable
        sectors = []
        consumer_staples_dummy = []

        for firm in self.df.index.get_level_values(0):
            if firm in consumer_staples_firms:
                sectors.append('Consumer Staples')
                consumer_staples_dummy.append(1)
            else:
                sectors.append('Other')
                consumer_staples_dummy.append(0)

        self.df['Sector'] = sectors
        self.df['ConsumerStaples'] = consumer_staples_dummy

        print(f"\n✓ Created sector variables:")
        print(f"  Consumer Staples firms: {self.df[self.df['ConsumerStaples']==1].index.get_level_values(0).nunique()}")
        print(f"  Other sectors firms: {self.df[self.df['ConsumerStaples']==0].index.get_level_values(0).nunique()}")
        print(f"  Consumer Staples observations: {self.df['ConsumerStaples'].sum()}")

        return self.df

    def create_aligned_change_variables(self, max_lag=5):
        """
        Create properly aligned change variables.
        For change over k years: ΔkESG(t-1) = ESG(t-1) - ESG(t-1-k)
        This change predicts Tobin's Q at time t.

        Parameters:
        -----------
        max_lag : int
            Maximum lag period to create
        """
        print(f"\n{'='*70}")
        print(f"CREATING ALIGNED CHANGE VARIABLES (t-1 ESG predicting t Tobin's Q)")
        print(f"Maximum lag period: {max_lag} years")
        print(f"{'='*70}")

        # Check which ESG components are available
        esg_components = [c for c in ['E', 'S', 'G'] if c in self.df.columns]
        print(f"Available ESG components: {esg_components}")

        if not esg_components:
            print("⚠ No ESG components found!")
            return self.df

        # Create lagged variables for all periods
        for lag in range(1, max_lag + 1):
            for component in esg_components:
                # Lagged ESG at t-1
                lag1_col = f'{component}_lag1'
                if lag1_col not in self.df.columns:
                    self.df[lag1_col] = self.df.groupby(level=0)[component].shift(1)

                # Lagged ESG at t-1-k (for k-year change)
                lag_kplus1_col = f'{component}_lag{lag+1}'
                if lag_kplus1_col not in self.df.columns and lag > 1:
                    self.df[lag_kplus1_col] = self.df.groupby(level=0)[component].shift(lag+1)

                # Also create simple lag k for level effects
                lag_k_col = f'{component}_lag{lag}'
                if lag_k_col not in self.df.columns:
                    self.df[lag_k_col] = self.df.groupby(level=0)[component].shift(lag)

        # Create change variables
        for lag in range(1, max_lag + 1):
            print(f"\nCreating {lag}-year change variables (Δ{lag}ESG(t-1) = ESG(t-1) - ESG(t-{lag+1})):")

            for component in esg_components:
                # Current ESG at t-1
                current = f'{component}_lag1'
                # Past ESG at t-1-lag
                past = f'{component}_lag{lag+1}'

                if current in self.df.columns and past in self.df.columns:
                    # Absolute change
                    change_col = f'{component}_chg{lag}_aligned'
                    self.df[change_col] = self.df[current] - self.df[past]

                    # Store metadata
                    self.change_data[change_col] = {
                        'component': component,
                        'lag_period': lag,
                        'type': 'absolute',
                        'formula': f'{component}(t-1) - {component}(t-{lag+1})'
                    }

                    non_null = self.df[change_col].notna().sum()
                    mean_val = self.df[change_col].mean()
                    print(f"  ✓ {change_col}: {non_null} non-null, mean={mean_val:.4f}")

                    # Percentage change (avoid division by zero)
                    pct_col = f'{component}_pctchg{lag}_aligned'
                    denominator = self.df[past].replace(0, np.nan)
                    self.df[pct_col] = (self.df[current] - self.df[past]) / denominator

                    self.change_data[pct_col] = {
                        'component': component,
                        'lag_period': lag,
                        'type': 'percentage',
                        'formula': f'[{component}(t-1) - {component}(t-{lag+1})] / {component}(t-{lag+1})'
                    }

                    non_null = self.df[pct_col].notna().sum()
                    mean_val = self.df[pct_col].mean()
                    print(f"  ✓ {pct_col}: {non_null} non-null, mean={mean_val:.4%}")

        # Summary
        change_cols = [col for col in self.df.columns if '_chg' in col or '_pctchg' in col]
        print(f"\n✓ Total aligned change variables created: {len(change_cols)}")

        return self.df

    def run_aligned_model(self, change_period=1, change_type='absolute',
                         y_var='Tobin_Q', sector='All', include_levels=True):
        """
        Run a properly aligned change in ESG model.
        Tobin's Q at time t is predicted by ESG changes from t-1-lag to t-1.

        Parameters:
        -----------
        change_period : int
            Period over which change is calculated (k years)
        change_type : str
            Type of change ('absolute' or 'percentage')
        y_var : str
            Dependent variable (Tobin's Q at time t)
        sector : str
            Sector to analyze ('All' or 'CS')
        include_levels : bool
            Whether to include lagged ESG levels (at t-1)
        """
        print(f"\n{'='*70}")
        print(f"ALIGNED CHANGE IN ESG MODEL")
        print(f"Change period: {change_period} year(s) [Δ from t-{change_period+1} to t-1]")
        print(f"Type: {change_type}, Sector: {sector}, Y: {y_var}, Include levels: {include_levels}")
        print(f"{'='*70}")

        # Filter data by sector
        if sector == 'CS':
            if 'ConsumerStaples' not in self.df.columns:
                self.create_sector_variable()
            df_filtered = self.df[self.df['ConsumerStaples'] == 1].copy()
        else:
            df_filtered = self.df.copy()
            if 'ConsumerStaples' not in self.df.columns:
                self.create_sector_variable()

        # Define change variable suffix
        suffix = 'chg' if change_type == 'absolute' else 'pctchg'
        aligned_suffix = f'{suffix}{change_period}_aligned'

        # Define model variables
        model_vars = []

        # Add change variables
        change_vars = []
        for component in ['E', 'S', 'G']:
            change_var = f'{component}_{aligned_suffix}'
            if change_var in df_filtered.columns:
                change_vars.append(change_var)
                model_vars.append(change_var)
            else:
                print(f"⚠ Change variable {change_var} not found")

        # Add lagged ESG levels (at t-1) if requested
        level_vars = []
        if include_levels:
            for component in ['E', 'S', 'G']:
                level_var = f'{component}_lag1'
                if level_var in df_filtered.columns:
                    level_vars.append(level_var)
                    model_vars.append(level_var)

        # Add control variables
        control_vars = []
        for var in ['ROA', 'Size', 'Leverage']:
            if var in df_filtered.columns:
                control_vars.append(var)
                model_vars.append(var)

        # Add sector dummy if analyzing all firms
        if sector == 'All':
            model_vars.append('ConsumerStaples')

        # Clean data - use y_var at time t, predictors at t-1 and changes
        all_vars = model_vars + [y_var]
        df_clean = df_filtered.dropna(subset=all_vars)

        if len(df_clean) < 10:
            print(f"✗ Insufficient data: Only {len(df_clean)} observations")
            return None

        # Print data summary
        print(f"\nData Summary:")
        print(f"  Observations: {len(df_clean)}")
        print(f"  Firms: {df_clean.index.get_level_values(0).nunique()}")
        print(f"  Years: {sorted(df_clean.index.get_level_values(1).unique())}")

        # Prepare data for regression
        y = df_clean[y_var]
        X = df_clean[model_vars]
        X = pd.concat([pd.Series(1, index=X.index, name='const'), X], axis=1)

        print(f"\nRegression variables:")
        print(f"  Y: {y_var} (time t)")
        print(f"  Change vars: {change_vars}")
        if include_levels:
            print(f"  Level vars (t-1): {level_vars}")
        print(f"  Controls: {control_vars}")

        try:
            # Run regression
            model = PanelOLS(y, X, entity_effects=False, time_effects=False)
            results = model.fit(cov_type='robust')

            # Store results
            model_key = f'Change_{change_period}yr_{change_type}_levels{include_levels}_{sector}_{y_var}'
            self.results[model_key] = {
                'results': results,
                'model_name': f'Change in ESG ({change_period}yr, {change_type})',
                'change_period': change_period,
                'change_type': change_type,
                'include_levels': include_levels,
                'y_var': y_var,
                'sector': sector,
                'nobs': results.nobs,
                'r2': results.rsquared,
                'change_vars': change_vars,
                'level_vars': level_vars if include_levels else [],
                'control_vars': control_vars
            }

            # Add to summary table with fixed column order
            summary_row = {
                'Model': f'{change_period}yr_{change_type}_{sector}',
                'Period': change_period,
                'Type': change_type,
                'Sector': sector,
                'Levels': include_levels,
                'Constant': results.params.get('const', np.nan),
                'E': results.params.get(f'E_{aligned_suffix}', np.nan),
                'S': results.params.get(f'S_{aligned_suffix}', np.nan),
                'G': results.params.get(f'G_{aligned_suffix}', np.nan),
                'E_lag1': results.params.get('E_lag1', np.nan) if include_levels else np.nan,
                'S_lag1': results.params.get('S_lag1', np.nan) if include_levels else np.nan,
                'G_lag1': results.params.get('G_lag1', np.nan) if include_levels else np.nan,
                'ROA': results.params.get('ROA', np.nan),
                'Size': results.params.get('Size', np.nan),
                'Leverage': results.params.get('Leverage', np.nan),
                'ConsumerStaples': results.params.get('ConsumerStaples', np.nan) if sector == 'All' else np.nan,
                'R2': results.rsquared,
                'N': results.nobs,
                'E_pval': results.pvalues.get(f'E_{aligned_suffix}', np.nan),
                'S_pval': results.pvalues.get(f'S_{aligned_suffix}', np.nan),
                'G_pval': results.pvalues.get(f'G_{aligned_suffix}', np.nan)
            }
            self.results_summary.append(summary_row)

            # Print results
            print(f"\n✓ Regression successful!")
            print(f"  R-squared: {results.rsquared:.4f}")
            print(f"  Observations: {results.nobs}")

            # Print change coefficients
            print(f"\nChange in ESG Coefficients ({change_type} change from t-{change_period+1} to t-1):")
            for component in ['E', 'S', 'G']:
                change_var = f'{component}_{aligned_suffix}'
                if change_var in results.params:
                    coeff = results.params[change_var]
                    pval = results.pvalues.get(change_var, 1.0)
                    sig = "***" if pval < 0.01 else "**" if pval < 0.05 else "*" if pval < 0.10 else ""
                    print(f"  Δ{component}: {coeff:.4f}{sig} (p={pval:.4f})")

            # Print level coefficients if included
            if include_levels:
                print(f"\nLagged ESG Levels (t-1):")
                for component in ['E', 'S', 'G']:
                    level_var = f'{component}_lag1'
                    if level_var in results.params:
                        coeff = results.params[level_var]
                        pval = results.pvalues.get(level_var, 1.0)
                        sig = "***" if pval < 0.01 else "**" if pval < 0.05 else "*" if pval < 0.10 else ""
                        print(f"  {component}(t-1): {coeff:.4f}{sig} (p={pval:.4f})")

            # Print control variables
            print(f"\nControl Variables:")
            for var in control_vars:
                if var in results.params:
                    coeff = results.params[var]
                    pval = results.pvalues.get(var, 1.0)
                    sig = "***" if pval < 0.01 else "**" if pval < 0.05 else "*" if pval < 0.10 else ""
                    print(f"  {var}: {coeff:.4f}{sig} (p={pval:.4f})")

            return results

        except Exception as e:
            print(f"\n✗ Error running regression: {e}")
            import traceback
            traceback.print_exc()
            return None

    def run_comprehensive_analysis(self, periods=None, change_types=None,
                                  y_var='Tobin_Q', sectors=None):
        """
        Run comprehensive change analysis for multiple periods.

        Parameters:
        -----------
        periods : list
            List of change periods to analyze (1-5 years)
        change_types : list
            List of change types ['absolute', 'percentage']
        y_var : str
            Dependent variable
        sectors : list
            List of sectors ['All', 'CS']
        """
        if periods is None:
            periods = [1, 2, 3, 4, 5]

        if change_types is None:
            change_types = ['absolute', 'percentage']

        if sectors is None:
            sectors = ['All', 'CS']

        print("=" * 70)
        print("COMPREHENSIVE ALIGNED CHANGE IN ESG ANALYSIS")
        print("=" * 70)
        print(f"Analyzing change periods: {periods} years")
        print(f"Change types: {change_types}")
        print(f"Sectors: {sectors}")
        print(f"Dependent variable: {y_var}")

        # Create all aligned change variables first
        self.create_aligned_change_variables(max_lag=max(periods))

        # Run models for each combination
        print("\n" + "=" * 70)
        print("RUNNING REGRESSION MODELS")
        print("=" * 70)

        for period in periods:
            for change_type in change_types:
                for sector in sectors:
                    for include_levels in [False, True]:
                        self.run_aligned_model(
                            change_period=period,
                            change_type=change_type,
                            y_var=y_var,
                            sector=sector,
                            include_levels=include_levels
                        )

        # Create and save summary tables
        self.create_summary_tables()

    def create_summary_tables(self):
        """
        Create formatted summary tables with consistent column ordering.
        """
        if not self.results_summary:
            print("No results to summarize")
            return

        # Convert to DataFrame
        summary_df = pd.DataFrame(self.results_summary)

        # Define column order for main coefficients table
        main_cols = ['Model', 'Period', 'Type', 'Sector', 'Levels',
                     'Constant', 'E', 'S', 'G',
                     'E_lag1', 'S_lag1', 'G_lag1',
                     'ROA', 'Size', 'Leverage', 'ConsumerStaples',
                     'R2', 'N']

        # Filter to available columns
        available_main_cols = [col for col in main_cols if col in summary_df.columns]
        main_table = summary_df[available_main_cols].copy()

        # Round numeric columns
        numeric_cols = ['Constant', 'E', 'S', 'G', 'E_lag1', 'S_lag1', 'G_lag1',
                       'ROA', 'Size', 'Leverage', 'ConsumerStaples', 'R2']
        for col in numeric_cols:
            if col in main_table.columns:
                main_table[col] = main_table[col].round(4)

        # Save main table
        main_path = os.path.join(self.output_dir, 'change_esg_coefficients.xlsx')
        main_table.to_excel(main_path, index=False)
        print(f"\n✓ Saved coefficients table to: {main_path}")

        # Create significance table
        sig_cols = ['Model', 'Period', 'Type', 'Sector', 'Levels',
                   'E_pval', 'S_pval', 'G_pval', 'R2', 'N']
        available_sig_cols = [col for col in sig_cols if col in summary_df.columns]
        sig_table = summary_df[available_sig_cols].copy()

        # Add significance stars
        for comp in ['E', 'S', 'G']:
            pval_col = f'{comp}_pval'
            star_col = f'{comp}_sig'
            if pval_col in sig_table.columns:
                sig_table[star_col] = sig_table[pval_col].apply(
                    lambda x: '***' if x < 0.01 else '**' if x < 0.05 else '*' if x < 0.10 else ''
                )

        # Round p-values
        for col in ['E_pval', 'S_pval', 'G_pval']:
            if col in sig_table.columns:
                sig_table[col] = sig_table[col].round(4)

        # Save significance table
        sig_path = os.path.join(self.output_dir, 'change_esg_significance.xlsx')
        sig_table.to_excel(sig_path, index=False)
        print(f"✓ Saved significance table to: {sig_path}")

        # Create separate sheets for different sectors and level specifications
        with pd.ExcelWriter(os.path.join(self.output_dir, 'change_esg_detailed.xlsx')) as writer:
            # All models
            main_table.to_excel(writer, sheet_name='All_Models', index=False)

            # By sector and levels
            for sector in ['All', 'CS']:
                for levels in [False, True]:
                    subset = main_table[(main_table['Sector'] == sector) &
                                       (main_table['Levels'] == levels)]
                    if not subset.empty:
                        sheet_name = f'{sector}_Levels{levels}'
                        subset.to_excel(writer, sheet_name=sheet_name, index=False)

        print(f"✓ Saved detailed tables to: {os.path.join(self.output_dir, 'change_esg_detailed.xlsx')}")

        # Display best models
        self.display_best_models(main_table)

    def display_best_models(self, main_table):
        """
        Display the best performing models.
        """
        print("\n" + "=" * 70)
        print("BEST MODELS BY R-SQUARED")
        print("=" * 70)

        # Overall best
        best_idx = main_table['R2'].idxmax()
        best = main_table.loc[best_idx]
        print("\n🏆 OVERALL BEST MODEL:")
        print(f"  Model: {best['Model']}")
        print(f"  R²: {best['R2']:.4f}")
        print(f"  N: {best['N']}")
        print(f"  Coefficients:")
        print(f"    E: {best['E']:.4f}")
        print(f"    S: {best['S']:.4f}")
        print(f"    G: {best['G']:.4f}")
        if 'E_lag1' in best and pd.notna(best['E_lag1']):
            print(f"    E(t-1): {best['E_lag1']:.4f}")
            print(f"    S(t-1): {best['S_lag1']:.4f}")
            print(f"    G(t-1): {best['G_lag1']:.4f}")
        print(f"    ROA: {best['ROA']:.4f}")
        print(f"    Size: {best['Size']:.4f}")
        print(f"    Leverage: {best['Leverage']:.4f}")

        # Best by sector
        for sector in ['All', 'CS']:
            sector_models = main_table[main_table['Sector'] == sector]
            if not sector_models.empty:
                best_sector_idx = sector_models['R2'].idxmax()
                best_sector = sector_models.loc[best_sector_idx]
                print(f"\n📊 BEST {sector} SECTOR MODEL:")
                print(f"  Model: {best_sector['Model']}")
                print(f"  R²: {best_sector['R2']:.4f}")
                print(f"  S coefficient: {best_sector['S']:.4f}")

        # Best by change period
        print("\n📈 BEST BY CHANGE PERIOD:")
        for period in sorted(main_table['Period'].unique()):
            period_models = main_table[main_table['Period'] == period]
            if not period_models.empty:
                best_period_idx = period_models['R2'].idxmax()
                best_period = period_models.loc[best_period_idx]
                print(f"  {period}-year: R²={best_period['R2']:.4f} ({best_period['Model']})")

    def save_results(self):
        """
        Save all results to Excel files.
        """
        print("\n" + "=" * 70)
        print("SAVING RESULTS")
        print("=" * 70)

        # Save change variables summary
        if self.change_data:
            change_summary = []
            for col_name, data_info in self.change_data.items():
                if col_name in self.df.columns:
                    non_null = self.df[col_name].notna().sum()
                    mean_val = self.df[col_name].mean()
                    std_val = self.df[col_name].std()

                    change_summary.append({
                        'Variable': col_name,
                        'Component': data_info['component'],
                        'Lag_Period': data_info['lag_period'],
                        'Type': data_info['type'],
                        'Formula': data_info['formula'],
                        'Non_Null': non_null,
                        'Mean': mean_val,
                        'Std': std_val
                    })

            if change_summary:
                change_df = pd.DataFrame(change_summary)
                change_path = os.path.join(self.output_dir, 'aligned_change_variables.xlsx')
                change_df.to_excel(change_path, index=False)
                print(f"✓ Saved aligned change variables to: {change_path}")

        print(f"\n✓ All results saved to: {self.output_dir}")


def main():
    """
    Main function to run the aligned Change in ESG analysis.
    """
    # Configuration
    DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/FTSE Data/FTSE data.xlsx'
    OUTPUT_DIR = '/content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output'

    print("=" * 70)
    print("ALIGNED CHANGE IN LAGGED ESG ANALYSIS")
    print("=" * 70)
    print("Proper timing: ESG changes from t-1-k to t-1 predict Tobin's Q at t")

    # Initialize analysis
    analyzer = ChangeESGAnalysis(DATA_PATH, OUTPUT_DIR)

    # Step 1: Load and prepare data
    print("\n" + "=" * 70)
    print("STEP 1: LOADING DATA")
    print("=" * 70)

    df = analyzer.load_and_prepare_data()

    if df is None:
        print("✗ Failed to load data. Exiting.")
        return

    # Step 2: Create sector variable
    print("\n" + "=" * 70)
    print("STEP 2: CREATING SECTOR VARIABLES")
    print("=" * 70)

    analyzer.create_sector_variable()

    # Step 3: Run comprehensive analysis for 1-5 years
    print("\n" + "=" * 70)
    print("STEP 3: COMPREHENSIVE ALIGNED ANALYSIS")
    print("=" * 70)

    analyzer.run_comprehensive_analysis(
        periods=[1, 2, 3, 4, 5],
        change_types=['absolute'],
        y_var='Tobin_Q',
        sectors=['All', 'CS']
    )

    # Step 4: Save all results
    print("\n" + "=" * 70)
    print("STEP 4: SAVING FINAL RESULTS")
    print("=" * 70)

    analyzer.save_results()

    print("\n" + "=" * 70)
    print("ANALYSIS COMPLETE")
    print("=" * 70)


if __name__ == "__main__":
    main()

# esg_change_model_with_robustness_fixed.py
"""
ESG Change Model Analysis with Robustness Checks
- Original code preserved exactly
- Robustness checks appended after main()
- Shows R² comparisons and sign/significance consistency
- Includes ALL periods (1-5 years)
"""


# ============================================================================
# EXECUTION
# ============================================================================
if __name__ == "__main__":
    main()

    # Re-create the analyzer to access data for robustness checks
    DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/FTSE Data/FTSE data.xlsx'
    OUTPUT_DIR = '/content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output'

    change_analyzer = ChangeESGAnalysis(DATA_PATH, OUTPUT_DIR)
    change_analyzer.load_and_prepare_data()
    change_analyzer.create_sector_variable()
    change_analyzer.create_aligned_change_variables(max_lag=5)

    # RUN THE COMPREHENSIVE ANALYSIS AGAIN to populate results_summary
    print("\n" + "="*70)
    print("RUNNING COMPREHENSIVE ANALYSIS FOR ROBUSTNESS CHECKS")
    print("="*70)

    # Explicitly set periods to include all 1-5 years
    periods_to_test = [1, 2, 3, 4, 5]

    change_analyzer.run_comprehensive_analysis(
        periods=periods_to_test,
        change_types=['absolute'],
        y_var='Tobin_Q',
        sectors=['All', 'CS']
    )

# ============================================================================
# ROBUSTNESS CHECKS FOR ESG CHANGE MODELS
# ============================================================================
print("\n" + "="*100)
print("ROBUSTNESS CHECKS FOR ESG CHANGE MODELS")
print("="*100)
print("Testing sensitivity to dependent variable transformations")
print("Using EXACT same data samples as main program for final models")

# Get the dataframes
df = change_analyzer.df

# First, capture the original results from the summary table
print("\n" + "-"*60)
print("ORIGINAL MODEL RESULTS (FROM MAIN PROGRAM)")
print("-"*60)

original_results = {}

if change_analyzer.results_summary:
    print(f"Found {len(change_analyzer.results_summary)} models in results_summary")

    # Show distribution by period
    period_counts = {}
    for row in change_analyzer.results_summary:
        period = row['Period']
        period_counts[period] = period_counts.get(period, 0) + 1

    print("\nModels by period:")
    for period in sorted(period_counts.keys()):
        print(f"  Period {period}: {period_counts[period]} models")

    for idx, row in enumerate(change_analyzer.results_summary):
        model_key = f"change_model_{idx}_{row['Model']}"

        # Store the results
        original_results[model_key] = {
            'model_type': 'change_model',
            'period': row['Period'],
            'sector': row['Sector'],
            'change_type': row['Type'],
            'include_levels': row['Levels'],
            'r2': row['R2'],
            'nobs': row['N'],
            'e_change': row.get('E', np.nan),
            'e_pval': row.get('E_pval', np.nan),
            's_change': row.get('S', np.nan),
            's_pval': row.get('S_pval', np.nan),
            'g_change': row.get('G', np.nan),
            'g_pval': row.get('G_pval', np.nan),
            'e_lag1': row.get('E_lag1', np.nan),
            's_lag1': row.get('S_lag1', np.nan),
            'g_lag1': row.get('G_lag1', np.nan)
        }

        # Only print a sample to avoid too much output
        if idx < 5 or idx % 10 == 0:
            print(f"\n{model_key}:")
            print(f"  Period: {row['Period']}yr, Sector: {row['Sector']}, Type: {row['Type']}")
            print(f"  Include levels: {row['Levels']}")
            print(f"  R² = {row['R2']:.6f}, N = {row['N']}")
else:
    print("⚠ No results found in results_summary!")

# Available transformations in the data
available_transforms = ['Tobin_Q_log', 'Tobin_Q_sqrt', 'Tobin_Q_inv', 'Tobin_Q_boxcox']

# Create missing transformations if needed
from scipy import stats

if 'Tobin_Q_log' not in df.columns:
    df['Tobin_Q_log'] = np.log(df['Tobin_Q'].clip(lower=0.001))
    print("\n✓ Created Tobin_Q_log")

if 'Tobin_Q_sqrt' not in df.columns:
    df['Tobin_Q_sqrt'] = np.sqrt(df['Tobin_Q'].clip(lower=0))
    print("✓ Created Tobin_Q_sqrt")

if 'Tobin_Q_inv' not in df.columns:
    with np.errstate(divide='ignore', invalid='ignore'):
        df['Tobin_Q_inv'] = 1 / df['Tobin_Q']
        df['Tobin_Q_inv'] = df['Tobin_Q_inv'].replace([np.inf, -np.inf], np.nan)
    print("✓ Created Tobin_Q_inv")

if 'Tobin_Q_boxcox' not in df.columns:
    try:
        if (df['Tobin_Q'].dropna() > 0).all():
            boxcox_data, lambda_param = stats.boxcox(df['Tobin_Q'].dropna() + 0.001)
            df['Tobin_Q_boxcox'] = np.nan
            df.loc[df['Tobin_Q'].dropna().index, 'Tobin_Q_boxcox'] = boxcox_data
            print(f"✓ Created Tobin_Q_boxcox (λ={lambda_param:.4f})")
    except:
        df['Tobin_Q_boxcox'] = np.nan

print(f"\nAvailable transformations: {[col for col in df.columns if 'Tobin_Q' in col and col != 'Tobin_Q']}")

# ============================================================================
# ROBUSTNESS CHECK: ALTERNATIVE TRANSFORMATIONS
# ============================================================================
print("\n" + "="*100)
print("ROBUSTNESS CHECK: ALTERNATIVE DEPENDENT VARIABLE TRANSFORMATIONS")
print("="*100)

# Define transformations to test
transformations = [
    ('Original', 'Tobin_Q'),
    ('Log', 'Tobin_Q_log'),
    ('Square Root', 'Tobin_Q_sqrt'),
    ('Inverse', 'Tobin_Q_inv'),
]

if 'Tobin_Q_boxcox' in df.columns and not df['Tobin_Q_boxcox'].isna().all():
    transformations.append(('Box-Cox', 'Tobin_Q_boxcox'))

# Store robustness results
robustness_results = {}
consistency_metrics = []

if not original_results:
    print("\n⚠ No original results found! Cannot perform robustness checks.")
else:
    # Select models to test - ensure we cover all periods
    print("\nSelecting models for robustness testing...")

    model_keys_to_test = []

    # First, try to get at least one model for each period, sector, and level combination
    for period in [1, 2, 3, 4, 5]:
        for sector in ['All', 'CS']:
            for levels in [False, True]:
                # Find a model with this combination
                found = False
                for key, info in original_results.items():
                    if (info['period'] == period and
                        info['sector'] == sector and
                        info['include_levels'] == levels):
                        if key not in model_keys_to_test:
                            model_keys_to_test.append(key)
                            print(f"  Added: Period {period}, {sector}, Levels={levels}")
                            found = True
                        break
                if not found:
                    print(f"  Not found: Period {period}, {sector}, Levels={levels}")

    # If we still have room, add more models
    if len(model_keys_to_test) < 15:
        for key, info in original_results.items():
            if key not in model_keys_to_test:
                model_keys_to_test.append(key)
                if len(model_keys_to_test) >= 20:
                    break

    print(f"\nAnalyzing {len(model_keys_to_test)} change models across all periods...")

    # Count by period in our test set
    test_periods = {}
    for key in model_keys_to_test:
        period = original_results[key]['period']
        test_periods[period] = test_periods.get(period, 0) + 1
    print("Models by period in test set:")
    for period in sorted(test_periods.keys()):
        print(f"  Period {period}: {test_periods[period]} models")

    for model_idx, model_key in enumerate(model_keys_to_test):
        model_info = original_results[model_key]

        print(f"\n" + "="*80)
        print(f"MODEL {model_idx+1}/{len(model_keys_to_test)}: {model_key[:60]}...")
        print("="*80)

        period = model_info['period']
        sector = model_info['sector']
        change_type = model_info['change_type']
        include_levels = model_info['include_levels']
        orig_r2 = model_info['r2']
        orig_n = model_info['nobs']

        print(f"Period: {period}yr, Sector: {sector}, Type: {change_type}")
        print(f"Include levels: {include_levels}")
        print(f"Original R² = {orig_r2:.6f}, N = {orig_n}")

        # Filter data by sector
        if sector == 'CS':
            df_model = df[df['ConsumerStaples'] == 1].copy()
            print(f"Filtered to Consumer Staples: {len(df_model)} observations")
        else:
            df_model = df.copy()
            print(f"Using All Sectors: {len(df_model)} observations")

        # Define change variable suffix
        suffix = f'chg{period}_aligned'

        # Define model variables
        model_vars = []

        # Add change variables
        change_vars = []
        for component in ['E', 'S', 'G']:
            change_var = f'{component}_{suffix}'
            if change_var in df_model.columns:
                # Check if variable has sufficient non-null values
                non_null = df_model[change_var].notna().sum()
                if non_null > 10:
                    change_vars.append(change_var)
                    model_vars.append(change_var)
                    print(f"  Found {change_var}: {non_null} non-null obs")
                else:
                    print(f"  ⚠ {change_var} has only {non_null} non-null obs - skipping")
            else:
                print(f"  ⚠ {change_var} not found in data")

        # Add lagged ESG levels if included
        level_vars = []
        if include_levels:
            for component in ['E', 'S', 'G']:
                level_var = f'{component}_lag1'
                if level_var in df_model.columns:
                    level_vars.append(level_var)
                    model_vars.append(level_var)

        # Add control variables
        control_vars = []
        for var in ['ROA', 'Size', 'Leverage']:
            if var in df_model.columns:
                control_vars.append(var)
                model_vars.append(var)

        # Add sector dummy if analyzing all firms
        if sector == 'All' and 'ConsumerStaples' in df_model.columns:
            model_vars.append('ConsumerStaples')

        if not change_vars:
            print(f"  ⚠ No change variables available for period {period}")
            continue

        print(f"Change variables: {change_vars}")
        if include_levels:
            print(f"Level variables: {level_vars}")
        print(f"Control variables: {control_vars}")

        # Store results for this model
        model_robustness = {}
        trans_results = []

        for trans_name, trans_var in transformations:
            print(f"\n  {trans_name.upper()} TRANSFORMATION:")

            if trans_var not in df_model.columns and trans_var in df.columns:
                df_model[trans_var] = df.loc[df_model.index, trans_var]

            if trans_var not in df_model.columns:
                print(f"    ✗ {trans_var} not available")
                model_robustness[trans_name] = None
                continue

            # Check if all required variables exist
            required_vars = model_vars + [trans_var]
            available_vars = [v for v in required_vars if v in df_model.columns]

            if len(available_vars) < len(required_vars):
                missing = set(required_vars) - set(available_vars)
                print(f"    ✗ Missing variables: {missing}")
                model_robustness[trans_name] = None
                continue

            # Drop NA for this transformation
            df_clean = df_model.dropna(subset=required_vars)

            if len(df_clean) < 10:
                print(f"    ✗ Insufficient data: {len(df_clean)} observations")
                model_robustness[trans_name] = None
                continue

            print(f"    Observations: {len(df_clean)}")

            # Run regression
            y = df_clean[trans_var]
            X = df_clean[model_vars]
            X = pd.concat([pd.Series(1, index=X.index, name='const'), X], axis=1)

            try:
                model = PanelOLS(y, X, entity_effects=False, time_effects=False)
                results = model.fit(cov_type='robust')

                # Calculate key metrics
                r2 = results.rsquared
                r2_diff = r2 - orig_r2

                # Get coefficient signs for change variables
                sign_matches = {}
                sig_matches = {}

                for comp in ['E', 'S', 'G']:
                    change_var = f'{comp}_{suffix}'
                    if change_var in results.params and pd.notna(model_info[f'{comp.lower()}_change']):
                        orig_coeff = model_info[f'{comp.lower()}_change']
                        new_coeff = results.params[change_var]
                        orig_pval = model_info[f'{comp.lower()}_pval']
                        new_pval = results.pvalues.get(change_var, 1.0)

                        orig_sig = orig_pval < 0.10
                        new_sig = new_pval < 0.10

                        # For inverse transformation, we expect signs to flip
                        if trans_name == 'Inverse':
                            # Expected sign flip: new coefficient should have opposite sign
                            sign_match = (np.sign(orig_coeff) == -np.sign(new_coeff)) if orig_coeff != 0 and new_coeff != 0 else True
                        else:
                            # For other transformations, signs should stay the same
                            sign_match = (np.sign(orig_coeff) == np.sign(new_coeff)) if orig_coeff != 0 and new_coeff != 0 else True

                        sig_match = (orig_sig == new_sig)

                        sign_matches[f'{comp}_change'] = sign_match
                        sig_matches[f'{comp}_change'] = sig_match

                # Also check level variables if included
                if include_levels:
                    for comp in ['E', 'S', 'G']:
                        level_var = f'{comp}_lag1'
                        if level_var in results.params and pd.notna(model_info[f'{comp.lower()}_lag1']):
                            orig_coeff = model_info[f'{comp.lower()}_lag1']
                            new_coeff = results.params[level_var]

                            # For inverse transformation, we expect signs to flip
                            if trans_name == 'Inverse':
                                sign_match = (np.sign(orig_coeff) == -np.sign(new_coeff)) if orig_coeff != 0 and new_coeff != 0 else True
                            else:
                                sign_match = (np.sign(orig_coeff) == np.sign(new_coeff)) if orig_coeff != 0 and new_coeff != 0 else True

                            sign_matches[f'{comp}_level'] = sign_match

                # Store results
                model_robustness[trans_name] = {
                    'r2': r2,
                    'r2_diff': r2_diff,
                    'nobs': results.nobs,
                    'sign_matches': sign_matches,
                    'sig_matches': sig_matches,
                    'results': results
                }

                # Calculate sign consistency percentage
                if sign_matches:
                    sign_consistency = sum(sign_matches.values()) / len(sign_matches) * 100
                else:
                    sign_consistency = None

                # Calculate significance consistency percentage (only for change variables)
                if sig_matches:
                    sig_consistency = sum(sig_matches.values()) / len(sig_matches) * 100
                else:
                    sig_consistency = None

                # Print summary
                print(f"    ✓ R² = {r2:.6f} (Δ = {r2_diff:+.6f})")
                if sign_consistency is not None:
                    expected = " (expected opposite)" if trans_name == 'Inverse' else ""
                    print(f"      Sign consistency{expected}: {sign_consistency:.1f}%")
                    for var, match in sign_matches.items():
                        print(f"        {var}: {'✓' if match else '✗'}")
                if sig_consistency is not None:
                    print(f"      Significance consistency: {sig_consistency:.1f}%")
                    for var, match in sig_matches.items():
                        if 'change' in var:  # Only show change variables significance
                            print(f"        {var}: {'✓' if match else '✗'}")

                trans_results.append({
                    'trans_name': trans_name,
                    'r2': r2,
                    'sign_consistency': sign_consistency,
                    'sig_consistency': sig_consistency,
                    'n_vars': len(sign_matches)
                })

            except Exception as e:
                print(f"    ✗ Failed: {str(e)[:100]}")
                model_robustness[trans_name] = None

        robustness_results[model_key] = model_robustness

        # Calculate overall consistency for this model
        if trans_results:
            print("\n  " + "-" * 40)
            print("  CHANGE MODEL CONSISTENCY SUMMARY")
            print("  " + "-" * 40)

            # R² stability
            r2_values = [r['r2'] for r in trans_results]
            print(f"  R² range: [{min(r2_values):.6f}, {max(r2_values):.6f}]")
            print(f"  R² stability (max-min): {max(r2_values) - min(r2_values):.6f}")

            # Average sign consistency (excluding inverse since it should flip)
            sign_vals_normal = [r['sign_consistency'] for r in trans_results
                               if r['sign_consistency'] is not None and r['trans_name'] != 'Inverse']
            if sign_vals_normal:
                avg_sign_normal = np.mean(sign_vals_normal)
                print(f"  Average sign consistency (excluding Inverse): {avg_sign_normal:.1f}%")
            else:
                avg_sign_normal = None

            # Inverse sign consistency (should be 0% if flipping correctly)
            inverse_result = next((r for r in trans_results if r['trans_name'] == 'Inverse'), None)
            if inverse_result and inverse_result['sign_consistency'] is not None:
                print(f"  Inverse sign consistency (should be 0% if flipping correctly): {inverse_result['sign_consistency']:.1f}%")

            # Average significance consistency
            sig_vals = [r['sig_consistency'] for r in trans_results if r['sig_consistency'] is not None]
            if sig_vals:
                avg_sig = np.mean(sig_vals)
                print(f"  Average significance consistency: {avg_sig:.1f}%")
            else:
                avg_sig = None

            # Store metrics
            consistency_metrics.append({
                'model_key': model_key[:50],
                'period': period,
                'sector': sector,
                'change_type': change_type,
                'include_levels': include_levels,
                'original_r2': orig_r2,
                'r2_min': min(r2_values),
                'r2_max': max(r2_values),
                'r2_range': max(r2_values) - min(r2_values),
                'avg_sign_consistency_normal': avg_sign_normal,
                'inverse_sign_consistency': inverse_result['sign_consistency'] if inverse_result else None,
                'avg_sig_consistency': avg_sig,
                'n_transformations': len(trans_results)
            })

# ============================================================================
# OVERALL ROBUSTNESS SUMMARY - ESG CHANGE MODELS
# ============================================================================
print("\n" + "="*100)
print("OVERALL ROBUSTNESS SUMMARY - ESG CHANGE MODELS")
print("="*100)

if consistency_metrics:
    summary_df = pd.DataFrame(consistency_metrics)

    # Format numeric columns
    for col in ['original_r2', 'r2_min', 'r2_max', 'r2_range']:
        if col in summary_df.columns:
            summary_df[col] = summary_df[col].round(6)

    for col in ['avg_sign_consistency_normal', 'inverse_sign_consistency', 'avg_sig_consistency']:
        if col in summary_df.columns:
            summary_df[col] = summary_df[col].round(1)

    print("\n" + "="*100)
    print("ESG CHANGE MODELS - ROBUSTNESS SUMMARY BY PERIOD")
    print("="*100)

    # Group by period
    for period in sorted(summary_df['period'].unique()):
        period_df = summary_df[summary_df['period'] == period]
        print(f"\n{'─'*50}")
        print(f"PERIOD: {period}-YEAR CHANGE ({len(period_df)} models)")
        print(f"{'─'*50}")

        for idx, row in period_df.iterrows():
            print(f"\n  Model: {row['sector']} Sector, Levels={row['include_levels']}")
            print(f"    Original R²: {row['original_r2']:.6f}")
            print(f"    R² range: [{row['r2_min']:.6f}, {row['r2_max']:.6f}] (Δ={row['r2_range']:.6f})")
            print(f"    Sign consistency: {row['avg_sign_consistency_normal']:.1f}%")
            print(f"    Inverse sign: {row['inverse_sign_consistency']:.1f}%")
            print(f"    Sig consistency: {row['avg_sig_consistency']:.1f}%")

    # Overall statistics by period
    print("\n" + "="*60)
    print("AVERAGE ROBUSTNESS BY PERIOD")
    print("="*60)

    period_avg = summary_df.groupby('period').agg({
        'avg_sign_consistency_normal': 'mean',
        'inverse_sign_consistency': 'mean',
        'avg_sig_consistency': 'mean',
        'r2_range': 'mean'
    }).round(1)

    period_avg.columns = ['Sign_Consistency_%', 'Inverse_%', 'Sig_Consistency_%', 'Avg_R2_Range']
    print(period_avg.to_string())

    # Overall assessment
    print("\n" + "="*60)
    print("OVERALL ROBUSTNESS ASSESSMENT")
    print("="*60)

    avg_sign_all = summary_df['avg_sign_consistency_normal'].mean()
    avg_sig_all = summary_df['avg_sig_consistency'].mean()
    avg_r2_range = summary_df['r2_range'].mean()

    print(f"\nAverage sign consistency across all models: {avg_sign_all:.1f}%")
    print(f"Average significance consistency: {avg_sig_all:.1f}%")
    print(f"Average R² range: {avg_r2_range:.6f}")

    if avg_sign_all >= 80:
        print("\n✅ CHANGE MODELS ARE HIGHLY ROBUST")
    elif avg_sign_all >= 60:
        print("\n⚠️ CHANGE MODELS ARE MODERATELY ROBUST")
    else:
        print("\n❌ CHANGE MODELS ARE NOT ROBUST")

# ============================================================================
# EXPORT ROBUSTNESS RESULTS TO EXCEL
# ============================================================================
print("\n" + "="*100)
print("EXPORTING ROBUSTNESS RESULTS TO EXCEL")
print("="*100)

try:
    timestamp = pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")
    robustness_path = os.path.join(change_analyzer.output_dir, f'change_model_robustness_all_periods_{timestamp}.xlsx')

    with pd.ExcelWriter(robustness_path, engine='openpyxl') as writer:
        sheets_created = False

        # Sheet 1: Overall Summary by Period
        if consistency_metrics:
            period_summary = summary_df.groupby('period').agg({
                'avg_sign_consistency_normal': ['mean', 'std'],
                'inverse_sign_consistency': ['mean', 'std'],
                'avg_sig_consistency': ['mean', 'std'],
                'r2_range': ['mean', 'std'],
                'model_key': 'count'
            }).round(1)
            period_summary.columns = ['Sign_Mean', 'Sign_Std', 'Inverse_Mean', 'Inverse_Std',
                                     'Sig_Mean', 'Sig_Std', 'R2_Range_Mean', 'R2_Range_Std', 'N_Models']
            period_summary.to_excel(writer, sheet_name='Period_Summary')
            sheets_created = True

        # Sheet 2: Detailed Results by Model
        if consistency_metrics:
            summary_df.to_excel(writer, sheet_name='All_Models_Detailed', index=False)
            sheets_created = True

        # Sheet 3: Detailed Results by Transformation
        detail_data = []
        for model_key, model_robust in robustness_results.items():
            for trans_name, trans_res in model_robust.items():
                if trans_res and isinstance(trans_res, dict):
                    # Get model info
                    model_info = original_results.get(model_key, {})

                    row = {
                        'Model': model_key[:50],
                        'Period': model_info.get('period', 'Unknown'),
                        'Sector': model_info.get('sector', 'Unknown'),
                        'Include_Levels': model_info.get('include_levels', False),
                        'Transformation': trans_name,
                        'R2': trans_res.get('r2'),
                        'R2_Diff': trans_res.get('r2_diff'),
                        'N': trans_res.get('nobs')
                    }

                    # Add sign matches
                    sign_matches = trans_res.get('sign_matches', {})
                    for var, match in sign_matches.items():
                        row[f'Sign_{var}'] = match

                    # Add significance matches
                    sig_matches = trans_res.get('sig_matches', {})
                    for var, match in sig_matches.items():
                        row[f'Sig_{var}'] = match

                    # Calculate overall percentages
                    if sign_matches:
                        row['Sign_Consistency_%'] = sum(sign_matches.values()) / len(sign_matches) * 100
                    if sig_matches:
                        row['Sig_Consistency_%'] = sum(sig_matches.values()) / len(sig_matches) * 100

                    detail_data.append(row)

        if detail_data:
            pd.DataFrame(detail_data).to_excel(writer, sheet_name='Transformation_Details', index=False)
            sheets_created = True

        # If no sheets created, add info
        if not sheets_created:
            pd.DataFrame({
                'Message': ['No robustness results available'],
                'Timestamp': [timestamp]
            }).to_excel(writer, sheet_name='Info', index=False)

    print(f"\n✓ Robustness results exported to: {robustness_path}")

except Exception as e:
    print(f"\n⚠ Could not export to Excel: {str(e)}")
    import traceback
    traceback.print_exc()

print("\n" + "="*100)
print("ROBUSTNESS CHECKS COMPLETE - ESG CHANGE MODELS (ALL PERIODS 1-5)")
print("="*100)
# Out:
# ======================================================================
# ALIGNED CHANGE IN LAGGED ESG ANALYSIS
# ======================================================================
# Proper timing: ESG changes from t-1-k to t-1 predict Tobin's Q at t
#
# ======================================================================
# STEP 1: LOADING DATA
# ======================================================================
# ======================================================================
# LOADING AND PREPARING DATA FOR CHANGE IN ESG ANALYSIS
# ======================================================================
# ✓ Loaded data from: /content/drive/MyDrive/Colab Notebooks/FTSE Data/FTSE data.xlsx
# ✓ Set multi-index (Firm, Year)
# ✓ Created Size variable (log of Total Assets)
# ✓ Created Leverage variable
# ✓ Found ESG columns: ['E', 'S', 'G']
#
# ✓ Loaded 388 observations
# ✓ Number of firms: 40
# ✓ Years: [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# ======================================================================
# STEP 2: CREATING SECTOR VARIABLES
# ======================================================================
#
# --------------------------------------------------
# CREATING SECTOR VARIABLES
# --------------------------------------------------
# Found 40 unique firms
# Found 8 Consumer Staples firms in data: ['Associated British Foods', 'British American Tobacco', 'Coca Cola HBC AG', 'Diageo', 'J. Sainsbury', 'Reckitt Benckiser', 'Tesco', 'Unilever']
#
# ✓ Created sector variables:
#   Consumer Staples firms: 8
#   Other sectors firms: 32
#   Consumer Staples observations: 80
#
# ======================================================================
# STEP 3: COMPREHENSIVE ALIGNED ANALYSIS
# ======================================================================
# ======================================================================
# COMPREHENSIVE ALIGNED CHANGE IN ESG ANALYSIS
# ======================================================================
# Analyzing change periods: [1, 2, 3, 4, 5] years
# Change types: ['absolute']
# Sectors: ['All', 'CS']
# Dependent variable: Tobin_Q
#
# ======================================================================
# CREATING ALIGNED CHANGE VARIABLES (t-1 ESG predicting t Tobin's Q)
# Maximum lag period: 5 years
# ======================================================================
# Available ESG components: ['E', 'S', 'G']
#
# Creating 1-year change variables (Δ1ESG(t-1) = ESG(t-1) - ESG(t-2)):
#   ✓ E_chg1_aligned: 308 non-null, mean=0.7012
#   ✓ E_pctchg1_aligned: 308 non-null, mean=3.1731%
#   ✓ S_chg1_aligned: 308 non-null, mean=0.6158
#   ✓ S_pctchg1_aligned: 308 non-null, mean=6.2503%
#   ✓ G_chg1_aligned: 308 non-null, mean=0.6753
#   ✓ G_pctchg1_aligned: 308 non-null, mean=4.0616%
#
# Creating 2-year change variables (Δ2ESG(t-1) = ESG(t-1) - ESG(t-3)):
#   ✓ E_chg2_aligned: 268 non-null, mean=1.8804
#   ✓ E_pctchg2_aligned: 268 non-null, mean=6.3404%
#   ✓ S_chg2_aligned: 268 non-null, mean=1.7010
#   ✓ S_pctchg2_aligned: 268 non-null, mean=9.1078%
#   ✓ G_chg2_aligned: 268 non-null, mean=1.6707
#   ✓ G_pctchg2_aligned: 268 non-null, mean=7.1523%
#
# Creating 3-year change variables (Δ3ESG(t-1) = ESG(t-1) - ESG(t-4)):
#   ✓ E_chg3_aligned: 229 non-null, mean=3.2701
#   ✓ E_pctchg3_aligned: 229 non-null, mean=9.4418%
#   ✓ S_chg3_aligned: 229 non-null, mean=2.5079
#   ✓ S_pctchg3_aligned: 229 non-null, mean=11.5133%
#   ✓ G_chg3_aligned: 229 non-null, mean=2.8553
#   ✓ G_pctchg3_aligned: 229 non-null, mean=10.6588%
#
# Creating 4-year change variables (Δ4ESG(t-1) = ESG(t-1) - ESG(t-5)):
#   ✓ E_chg4_aligned: 190 non-null, mean=4.1552
#   ✓ E_pctchg4_aligned: 190 non-null, mean=10.1995%
#   ✓ S_chg4_aligned: 190 non-null, mean=2.9538
#   ✓ S_pctchg4_aligned: 190 non-null, mean=6.7620%
#   ✓ G_chg4_aligned: 190 non-null, mean=4.1365
#   ✓ G_pctchg4_aligned: 190 non-null, mean=11.0983%
#
# Creating 5-year change variables (Δ5ESG(t-1) = ESG(t-1) - ESG(t-6)):
#   ✓ E_chg5_aligned: 152 non-null, mean=5.1940
#   ✓ E_pctchg5_aligned: 152 non-null, mean=12.4377%
#   ✓ S_chg5_aligned: 152 non-null, mean=3.6922
#   ✓ S_pctchg5_aligned: 152 non-null, mean=8.4513%
#   ✓ G_chg5_aligned: 152 non-null, mean=5.1706
#   ✓ G_pctchg5_aligned: 152 non-null, mean=13.8681%
#
# ✓ Total aligned change variables created: 30
#
# ======================================================================
# RUNNING REGRESSION MODELS
# ======================================================================
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 308
#   Firms: 40
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4082
#   Observations: 308
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: -0.0010 (p=0.8449)
#   ΔS: -0.0024 (p=0.7532)
#   ΔG: -0.0009 (p=0.8267)
#
# Control Variables:
#   ROA: 3.4855*** (p=0.0000)
#   Size: -0.2680*** (p=0.0000)
#   Leverage: 0.5090** (p=0.0169)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 308
#   Firms: 40
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4715
#   Observations: 308
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: 0.0022 (p=0.6631)
#   ΔS: -0.0092 (p=0.1996)
#   ΔG: -0.0000 (p=0.9942)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0068** (p=0.0214)
#   S(t-1): 0.0175*** (p=0.0000)
#   G(t-1): -0.0009 (p=0.7118)
#
# Control Variables:
#   ROA: 2.9078*** (p=0.0001)
#   Size: -0.3024*** (p=0.0000)
#   Leverage: 0.7547*** (p=0.0014)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 64
#   Firms: 8
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.3095
#   Observations: 64
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: -0.0141 (p=0.2746)
#   ΔS: 0.0123 (p=0.3733)
#   ΔG: -0.0013 (p=0.8684)
#
# Control Variables:
#   ROA: 5.5210*** (p=0.0076)
#   Size: -0.1914*** (p=0.0007)
#   Leverage: 1.1950** (p=0.0115)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 64
#   Firms: 8
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.5162
#   Observations: 64
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: -0.0103 (p=0.4143)
#   ΔS: -0.0056 (p=0.6630)
#   ΔG: 0.0042 (p=0.5376)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0103 (p=0.2059)
#   S(t-1): 0.0203*** (p=0.0055)
#   G(t-1): -0.0120*** (p=0.0044)
#
# Control Variables:
#   ROA: 4.1374*** (p=0.0058)
#   Size: -0.2485*** (p=0.0000)
#   Leverage: 1.5818** (p=0.0241)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 268
#   Firms: 39
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4014
#   Observations: 268
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0052 (p=0.2672)
#   ΔS: 0.0012 (p=0.8366)
#   ΔG: -0.0029 (p=0.3406)
#
# Control Variables:
#   ROA: 3.7002*** (p=0.0001)
#   Size: -0.2765*** (p=0.0000)
#   Leverage: 0.6059** (p=0.0135)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 268
#   Firms: 39
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4696
#   Observations: 268
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0010 (p=0.8199)
#   ΔS: -0.0058 (p=0.2948)
#   ΔG: -0.0031 (p=0.3396)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0078** (p=0.0195)
#   S(t-1): 0.0188*** (p=0.0000)
#   G(t-1): 0.0001 (p=0.9789)
#
# Control Variables:
#   ROA: 2.9719*** (p=0.0016)
#   Size: -0.3159*** (p=0.0000)
#   Leverage: 0.9170*** (p=0.0005)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 56
#   Firms: 8
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4399
#   Observations: 56
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0259*** (p=0.0048)
#   ΔS: 0.0294*** (p=0.0039)
#   ΔG: -0.0060 (p=0.2061)
#
# Control Variables:
#   ROA: 5.1159** (p=0.0194)
#   Size: -0.1509*** (p=0.0064)
#   Leverage: 1.3513*** (p=0.0048)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 56
#   Firms: 8
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.6136
#   Observations: 56
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0262** (p=0.0276)
#   ΔS: 0.0124 (p=0.3199)
#   ΔG: -0.0011 (p=0.8425)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0216* (p=0.0647)
#   S(t-1): 0.0089 (p=0.4457)
#   G(t-1): -0.0099* (p=0.0611)
#
# Control Variables:
#   ROA: 3.8335** (p=0.0237)
#   Size: -0.2038*** (p=0.0002)
#   Leverage: 2.5513*** (p=0.0065)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 229
#   Firms: 39
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.3964
#   Observations: 229
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0062 (p=0.1698)
#   ΔS: 0.0021 (p=0.7312)
#   ΔG: -0.0044 (p=0.1527)
#
# Control Variables:
#   ROA: 3.7591*** (p=0.0003)
#   Size: -0.2704*** (p=0.0000)
#   Leverage: 0.5609** (p=0.0412)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 229
#   Firms: 39
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4650
#   Observations: 229
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0017 (p=0.7092)
#   ΔS: -0.0050 (p=0.3976)
#   ΔG: -0.0031 (p=0.3706)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0083** (p=0.0293)
#   S(t-1): 0.0193*** (p=0.0000)
#   G(t-1): -0.0008 (p=0.8048)
#
# Control Variables:
#   ROA: 3.0332*** (p=0.0027)
#   Size: -0.3051*** (p=0.0000)
#   Leverage: 0.9265*** (p=0.0021)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 48
#   Firms: 8
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4778
#   Observations: 48
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0262*** (p=0.0027)
#   ΔS: 0.0293*** (p=0.0053)
#   ΔG: -0.0050 (p=0.3626)
#
# Control Variables:
#   ROA: 4.9175** (p=0.0453)
#   Size: -0.1309** (p=0.0323)
#   Leverage: 1.5892*** (p=0.0081)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 48
#   Firms: 8
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.6696
#   Observations: 48
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0250** (p=0.0265)
#   ΔS: 0.0006 (p=0.9679)
#   ΔG: 0.0073 (p=0.2394)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0353*** (p=0.0004)
#   S(t-1): 0.0042 (p=0.6802)
#   G(t-1): -0.0127* (p=0.0701)
#
# Control Variables:
#   ROA: 3.7116** (p=0.0462)
#   Size: -0.1828*** (p=0.0028)
#   Leverage: 3.8748*** (p=0.0002)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 190
#   Firms: 38
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4062
#   Observations: 190
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: -0.0023 (p=0.6055)
#   ΔS: 0.0010 (p=0.8883)
#   ΔG: -0.0048* (p=0.0749)
#
# Control Variables:
#   ROA: 4.3808*** (p=0.0000)
#   Size: -0.2589*** (p=0.0000)
#   Leverage: 0.7445** (p=0.0131)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 190
#   Firms: 38
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4769
#   Observations: 190
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: 0.0016 (p=0.7296)
#   ΔS: -0.0065 (p=0.3335)
#   ΔG: -0.0040 (p=0.2205)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0097** (p=0.0270)
#   S(t-1): 0.0191*** (p=0.0000)
#   G(t-1): 0.0001 (p=0.9707)
#
# Control Variables:
#   ROA: 3.6510*** (p=0.0001)
#   Size: -0.2893*** (p=0.0000)
#   Leverage: 1.1506*** (p=0.0003)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 40
#   Firms: 8
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.7066
#   Observations: 40
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: -0.0297*** (p=0.0001)
#   ΔS: 0.0390*** (p=0.0000)
#   ΔG: -0.0053 (p=0.3377)
#
# Control Variables:
#   ROA: 4.1980* (p=0.0526)
#   Size: -0.0919 (p=0.1411)
#   Leverage: 2.2072*** (p=0.0000)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 40
#   Firms: 8
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.8431
#   Observations: 40
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: -0.0380*** (p=0.0000)
#   ΔS: 0.0193* (p=0.0589)
#   ΔG: -0.0017 (p=0.5789)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0435*** (p=0.0000)
#   S(t-1): -0.0049 (p=0.5472)
#   G(t-1): -0.0091 (p=0.1159)
#
# Control Variables:
#   ROA: 2.7327** (p=0.0282)
#   Size: -0.1013 (p=0.1039)
#   Leverage: 4.7965*** (p=0.0000)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 152
#   Firms: 38
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4076
#   Observations: 152
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0038 (p=0.4549)
#   ΔS: 0.0073 (p=0.2189)
#   ΔG: -0.0044 (p=0.1358)
#
# Control Variables:
#   ROA: 4.3082*** (p=0.0001)
#   Size: -0.2473*** (p=0.0000)
#   Leverage: 0.8342*** (p=0.0067)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 152
#   Firms: 38
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4818
#   Observations: 152
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0008 (p=0.8803)
#   ΔS: 0.0001 (p=0.9841)
#   ΔG: -0.0016 (p=0.6814)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0082* (p=0.0809)
#   S(t-1): 0.0198*** (p=0.0000)
#   G(t-1): -0.0024 (p=0.5939)
#
# Control Variables:
#   ROA: 3.5514*** (p=0.0016)
#   Size: -0.2803*** (p=0.0000)
#   Leverage: 1.2256*** (p=0.0001)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 32
#   Firms: 8
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.7979
#   Observations: 32
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0350*** (p=0.0000)
#   ΔS: 0.0407*** (p=0.0000)
#   ΔG: -0.0056 (p=0.2408)
#
# Control Variables:
#   ROA: 2.4269* (p=0.0709)
#   Size: -0.0787 (p=0.2725)
#   Leverage: 2.3226*** (p=0.0004)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 32
#   Firms: 8
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.8467
#   Observations: 32
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0403*** (p=0.0000)
#   ΔS: 0.0304** (p=0.0140)
#   ΔG: -0.0020 (p=0.7368)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0279** (p=0.0235)
#   S(t-1): -0.0035 (p=0.6528)
#   G(t-1): -0.0087* (p=0.0947)
#
# Control Variables:
#   ROA: 1.9016* (p=0.0855)
#   Size: -0.0545 (p=0.2574)
#   Leverage: 3.9184*** (p=0.0001)
#
# ✓ Saved coefficients table to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/change_esg_coefficients.xlsx
# ✓ Saved significance table to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/change_esg_significance.xlsx
# ✓ Saved detailed tables to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/change_esg_detailed.xlsx
#
# ======================================================================
# BEST MODELS BY R-SQUARED
# ======================================================================
#
# 🏆 OVERALL BEST MODEL:
#   Model: 5yr_absolute_CS
#   R²: 0.8467
#   N: 32
#   Coefficients:
#     E: -0.0403
#     S: 0.0304
#     G: -0.0020
#     E(t-1): 0.0279
#     S(t-1): -0.0035
#     G(t-1): -0.0087
#     ROA: 1.9016
#     Size: -0.0545
#     Leverage: 3.9184
#
# 📊 BEST All SECTOR MODEL:
#   Model: 5yr_absolute_All
#   R²: 0.4818
#   S coefficient: 0.0001
#
# 📊 BEST CS SECTOR MODEL:
#   Model: 5yr_absolute_CS
#   R²: 0.8467
#   S coefficient: 0.0304
#
# 📈 BEST BY CHANGE PERIOD:
#   1-year: R²=0.5162 (1yr_absolute_CS)
#   2-year: R²=0.6136 (2yr_absolute_CS)
#   3-year: R²=0.6696 (3yr_absolute_CS)
#   4-year: R²=0.8431 (4yr_absolute_CS)
#   5-year: R²=0.8467 (5yr_absolute_CS)
#
# ======================================================================
# STEP 4: SAVING FINAL RESULTS
# ======================================================================
#
# ======================================================================
# SAVING RESULTS
# ======================================================================
# ✓ Saved aligned change variables to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/aligned_change_variables.xlsx
#
# ✓ All results saved to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output
#
# ======================================================================
# ANALYSIS COMPLETE
# ======================================================================
# ======================================================================
# ALIGNED CHANGE IN LAGGED ESG ANALYSIS
# ======================================================================
# Proper timing: ESG changes from t-1-k to t-1 predict Tobin's Q at t
#
# ======================================================================
# STEP 1: LOADING DATA
# ======================================================================
# ======================================================================
# LOADING AND PREPARING DATA FOR CHANGE IN ESG ANALYSIS
# ======================================================================
# ✓ Loaded data from: /content/drive/MyDrive/Colab Notebooks/FTSE Data/FTSE data.xlsx
# ✓ Set multi-index (Firm, Year)
# ✓ Created Size variable (log of Total Assets)
# ✓ Created Leverage variable
# ✓ Found ESG columns: ['E', 'S', 'G']
#
# ✓ Loaded 388 observations
# ✓ Number of firms: 40
# ✓ Years: [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# ======================================================================
# STEP 2: CREATING SECTOR VARIABLES
# ======================================================================
#
# --------------------------------------------------
# CREATING SECTOR VARIABLES
# --------------------------------------------------
# Found 40 unique firms
# Found 8 Consumer Staples firms in data: ['Associated British Foods', 'British American Tobacco', 'Coca Cola HBC AG', 'Diageo', 'J. Sainsbury', 'Reckitt Benckiser', 'Tesco', 'Unilever']
#
# ✓ Created sector variables:
#   Consumer Staples firms: 8
#   Other sectors firms: 32
#   Consumer Staples observations: 80
#
# ======================================================================
# STEP 3: COMPREHENSIVE ALIGNED ANALYSIS
# ======================================================================
# ======================================================================
# COMPREHENSIVE ALIGNED CHANGE IN ESG ANALYSIS
# ======================================================================
# Analyzing change periods: [1, 2, 3, 4, 5] years
# Change types: ['absolute']
# Sectors: ['All', 'CS']
# Dependent variable: Tobin_Q
#
# ======================================================================
# CREATING ALIGNED CHANGE VARIABLES (t-1 ESG predicting t Tobin's Q)
# Maximum lag period: 5 years
# ======================================================================
# Available ESG components: ['E', 'S', 'G']
#
# Creating 1-year change variables (Δ1ESG(t-1) = ESG(t-1) - ESG(t-2)):
#   ✓ E_chg1_aligned: 308 non-null, mean=0.7012
#   ✓ E_pctchg1_aligned: 308 non-null, mean=3.1731%
#   ✓ S_chg1_aligned: 308 non-null, mean=0.6158
#   ✓ S_pctchg1_aligned: 308 non-null, mean=6.2503%
#   ✓ G_chg1_aligned: 308 non-null, mean=0.6753
#   ✓ G_pctchg1_aligned: 308 non-null, mean=4.0616%
#
# Creating 2-year change variables (Δ2ESG(t-1) = ESG(t-1) - ESG(t-3)):
#   ✓ E_chg2_aligned: 268 non-null, mean=1.8804
#   ✓ E_pctchg2_aligned: 268 non-null, mean=6.3404%
#   ✓ S_chg2_aligned: 268 non-null, mean=1.7010
#   ✓ S_pctchg2_aligned: 268 non-null, mean=9.1078%
#   ✓ G_chg2_aligned: 268 non-null, mean=1.6707
#   ✓ G_pctchg2_aligned: 268 non-null, mean=7.1523%
#
# Creating 3-year change variables (Δ3ESG(t-1) = ESG(t-1) - ESG(t-4)):
#   ✓ E_chg3_aligned: 229 non-null, mean=3.2701
#   ✓ E_pctchg3_aligned: 229 non-null, mean=9.4418%
#   ✓ S_chg3_aligned: 229 non-null, mean=2.5079
#   ✓ S_pctchg3_aligned: 229 non-null, mean=11.5133%
#   ✓ G_chg3_aligned: 229 non-null, mean=2.8553
#   ✓ G_pctchg3_aligned: 229 non-null, mean=10.6588%
#
# Creating 4-year change variables (Δ4ESG(t-1) = ESG(t-1) - ESG(t-5)):
#   ✓ E_chg4_aligned: 190 non-null, mean=4.1552
#   ✓ E_pctchg4_aligned: 190 non-null, mean=10.1995%
#   ✓ S_chg4_aligned: 190 non-null, mean=2.9538
#   ✓ S_pctchg4_aligned: 190 non-null, mean=6.7620%
#   ✓ G_chg4_aligned: 190 non-null, mean=4.1365
#   ✓ G_pctchg4_aligned: 190 non-null, mean=11.0983%
#
# Creating 5-year change variables (Δ5ESG(t-1) = ESG(t-1) - ESG(t-6)):
#   ✓ E_chg5_aligned: 152 non-null, mean=5.1940
#   ✓ E_pctchg5_aligned: 152 non-null, mean=12.4377%
#   ✓ S_chg5_aligned: 152 non-null, mean=3.6922
#   ✓ S_pctchg5_aligned: 152 non-null, mean=8.4513%
#   ✓ G_chg5_aligned: 152 non-null, mean=5.1706
#   ✓ G_pctchg5_aligned: 152 non-null, mean=13.8681%
#
# ✓ Total aligned change variables created: 30
#
# ======================================================================
# RUNNING REGRESSION MODELS
# ======================================================================
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 308
#   Firms: 40
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4082
#   Observations: 308
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: -0.0010 (p=0.8449)
#   ΔS: -0.0024 (p=0.7532)
#   ΔG: -0.0009 (p=0.8267)
#
# Control Variables:
#   ROA: 3.4855*** (p=0.0000)
#   Size: -0.2680*** (p=0.0000)
#   Leverage: 0.5090** (p=0.0169)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 308
#   Firms: 40
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4715
#   Observations: 308
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: 0.0022 (p=0.6631)
#   ΔS: -0.0092 (p=0.1996)
#   ΔG: -0.0000 (p=0.9942)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0068** (p=0.0214)
#   S(t-1): 0.0175*** (p=0.0000)
#   G(t-1): -0.0009 (p=0.7118)
#
# Control Variables:
#   ROA: 2.9078*** (p=0.0001)
#   Size: -0.3024*** (p=0.0000)
#   Leverage: 0.7547*** (p=0.0014)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 64
#   Firms: 8
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.3095
#   Observations: 64
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: -0.0141 (p=0.2746)
#   ΔS: 0.0123 (p=0.3733)
#   ΔG: -0.0013 (p=0.8684)
#
# Control Variables:
#   ROA: 5.5210*** (p=0.0076)
#   Size: -0.1914*** (p=0.0007)
#   Leverage: 1.1950** (p=0.0115)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 1 year(s) [Δ from t-2 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 64
#   Firms: 8
#   Years: [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg1_aligned', 'S_chg1_aligned', 'G_chg1_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.5162
#   Observations: 64
#
# Change in ESG Coefficients (absolute change from t-2 to t-1):
#   ΔE: -0.0103 (p=0.4143)
#   ΔS: -0.0056 (p=0.6630)
#   ΔG: 0.0042 (p=0.5376)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0103 (p=0.2059)
#   S(t-1): 0.0203*** (p=0.0055)
#   G(t-1): -0.0120*** (p=0.0044)
#
# Control Variables:
#   ROA: 4.1374*** (p=0.0058)
#   Size: -0.2485*** (p=0.0000)
#   Leverage: 1.5818** (p=0.0241)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 268
#   Firms: 39
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4014
#   Observations: 268
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0052 (p=0.2672)
#   ΔS: 0.0012 (p=0.8366)
#   ΔG: -0.0029 (p=0.3406)
#
# Control Variables:
#   ROA: 3.7002*** (p=0.0001)
#   Size: -0.2765*** (p=0.0000)
#   Leverage: 0.6059** (p=0.0135)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 268
#   Firms: 39
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4696
#   Observations: 268
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0010 (p=0.8199)
#   ΔS: -0.0058 (p=0.2948)
#   ΔG: -0.0031 (p=0.3396)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0078** (p=0.0195)
#   S(t-1): 0.0188*** (p=0.0000)
#   G(t-1): 0.0001 (p=0.9789)
#
# Control Variables:
#   ROA: 2.9719*** (p=0.0016)
#   Size: -0.3159*** (p=0.0000)
#   Leverage: 0.9170*** (p=0.0005)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 56
#   Firms: 8
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4399
#   Observations: 56
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0259*** (p=0.0048)
#   ΔS: 0.0294*** (p=0.0039)
#   ΔG: -0.0060 (p=0.2061)
#
# Control Variables:
#   ROA: 5.1159** (p=0.0194)
#   Size: -0.1509*** (p=0.0064)
#   Leverage: 1.3513*** (p=0.0048)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 2 year(s) [Δ from t-3 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 56
#   Firms: 8
#   Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg2_aligned', 'S_chg2_aligned', 'G_chg2_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.6136
#   Observations: 56
#
# Change in ESG Coefficients (absolute change from t-3 to t-1):
#   ΔE: -0.0262** (p=0.0276)
#   ΔS: 0.0124 (p=0.3199)
#   ΔG: -0.0011 (p=0.8425)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0216* (p=0.0647)
#   S(t-1): 0.0089 (p=0.4457)
#   G(t-1): -0.0099* (p=0.0611)
#
# Control Variables:
#   ROA: 3.8335** (p=0.0237)
#   Size: -0.2038*** (p=0.0002)
#   Leverage: 2.5513*** (p=0.0065)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 229
#   Firms: 39
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.3964
#   Observations: 229
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0062 (p=0.1698)
#   ΔS: 0.0021 (p=0.7312)
#   ΔG: -0.0044 (p=0.1527)
#
# Control Variables:
#   ROA: 3.7591*** (p=0.0003)
#   Size: -0.2704*** (p=0.0000)
#   Leverage: 0.5609** (p=0.0412)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 229
#   Firms: 39
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4650
#   Observations: 229
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0017 (p=0.7092)
#   ΔS: -0.0050 (p=0.3976)
#   ΔG: -0.0031 (p=0.3706)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0083** (p=0.0293)
#   S(t-1): 0.0193*** (p=0.0000)
#   G(t-1): -0.0008 (p=0.8048)
#
# Control Variables:
#   ROA: 3.0332*** (p=0.0027)
#   Size: -0.3051*** (p=0.0000)
#   Leverage: 0.9265*** (p=0.0021)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 48
#   Firms: 8
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4778
#   Observations: 48
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0262*** (p=0.0027)
#   ΔS: 0.0293*** (p=0.0053)
#   ΔG: -0.0050 (p=0.3626)
#
# Control Variables:
#   ROA: 4.9175** (p=0.0453)
#   Size: -0.1309** (p=0.0323)
#   Leverage: 1.5892*** (p=0.0081)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 3 year(s) [Δ from t-4 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 48
#   Firms: 8
#   Years: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg3_aligned', 'S_chg3_aligned', 'G_chg3_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.6696
#   Observations: 48
#
# Change in ESG Coefficients (absolute change from t-4 to t-1):
#   ΔE: -0.0250** (p=0.0265)
#   ΔS: 0.0006 (p=0.9679)
#   ΔG: 0.0073 (p=0.2394)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0353*** (p=0.0004)
#   S(t-1): 0.0042 (p=0.6802)
#   G(t-1): -0.0127* (p=0.0701)
#
# Control Variables:
#   ROA: 3.7116** (p=0.0462)
#   Size: -0.1828*** (p=0.0028)
#   Leverage: 3.8748*** (p=0.0002)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 190
#   Firms: 38
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4062
#   Observations: 190
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: -0.0023 (p=0.6055)
#   ΔS: 0.0010 (p=0.8883)
#   ΔG: -0.0048* (p=0.0749)
#
# Control Variables:
#   ROA: 4.3808*** (p=0.0000)
#   Size: -0.2589*** (p=0.0000)
#   Leverage: 0.7445** (p=0.0131)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 190
#   Firms: 38
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4769
#   Observations: 190
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: 0.0016 (p=0.7296)
#   ΔS: -0.0065 (p=0.3335)
#   ΔG: -0.0040 (p=0.2205)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0097** (p=0.0270)
#   S(t-1): 0.0191*** (p=0.0000)
#   G(t-1): 0.0001 (p=0.9707)
#
# Control Variables:
#   ROA: 3.6510*** (p=0.0001)
#   Size: -0.2893*** (p=0.0000)
#   Leverage: 1.1506*** (p=0.0003)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 40
#   Firms: 8
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.7066
#   Observations: 40
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: -0.0297*** (p=0.0001)
#   ΔS: 0.0390*** (p=0.0000)
#   ΔG: -0.0053 (p=0.3377)
#
# Control Variables:
#   ROA: 4.1980* (p=0.0526)
#   Size: -0.0919 (p=0.1411)
#   Leverage: 2.2072*** (p=0.0000)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 4 year(s) [Δ from t-5 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 40
#   Firms: 8
#   Years: [2020, 2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg4_aligned', 'S_chg4_aligned', 'G_chg4_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.8431
#   Observations: 40
#
# Change in ESG Coefficients (absolute change from t-5 to t-1):
#   ΔE: -0.0380*** (p=0.0000)
#   ΔS: 0.0193* (p=0.0589)
#   ΔG: -0.0017 (p=0.5789)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0435*** (p=0.0000)
#   S(t-1): -0.0049 (p=0.5472)
#   G(t-1): -0.0091 (p=0.1159)
#
# Control Variables:
#   ROA: 2.7327** (p=0.0282)
#   Size: -0.1013 (p=0.1039)
#   Leverage: 4.7965*** (p=0.0000)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 152
#   Firms: 38
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4076
#   Observations: 152
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0038 (p=0.4549)
#   ΔS: 0.0073 (p=0.2189)
#   ΔG: -0.0044 (p=0.1358)
#
# Control Variables:
#   ROA: 4.3082*** (p=0.0001)
#   Size: -0.2473*** (p=0.0000)
#   Leverage: 0.8342*** (p=0.0067)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: All, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 152
#   Firms: 38
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.4818
#   Observations: 152
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0008 (p=0.8803)
#   ΔS: 0.0001 (p=0.9841)
#   ΔG: -0.0016 (p=0.6814)
#
# Lagged ESG Levels (t-1):
#   E(t-1): -0.0082* (p=0.0809)
#   S(t-1): 0.0198*** (p=0.0000)
#   G(t-1): -0.0024 (p=0.5939)
#
# Control Variables:
#   ROA: 3.5514*** (p=0.0016)
#   Size: -0.2803*** (p=0.0000)
#   Leverage: 1.2256*** (p=0.0001)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: False
# ======================================================================
#
# Data Summary:
#   Observations: 32
#   Firms: 8
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.7979
#   Observations: 32
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0350*** (p=0.0000)
#   ΔS: 0.0407*** (p=0.0000)
#   ΔG: -0.0056 (p=0.2408)
#
# Control Variables:
#   ROA: 2.4269* (p=0.0709)
#   Size: -0.0787 (p=0.2725)
#   Leverage: 2.3226*** (p=0.0004)
#
# ======================================================================
# ALIGNED CHANGE IN ESG MODEL
# Change period: 5 year(s) [Δ from t-6 to t-1]
# Type: absolute, Sector: CS, Y: Tobin_Q, Include levels: True
# ======================================================================
#
# Data Summary:
#   Observations: 32
#   Firms: 8
#   Years: [2021, 2022, 2023, 2024]
#
# Regression variables:
#   Y: Tobin_Q (time t)
#   Change vars: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
#   Level vars (t-1): ['E_lag1', 'S_lag1', 'G_lag1']
#   Controls: ['ROA', 'Size', 'Leverage']
#
# ✓ Regression successful!
#   R-squared: 0.8467
#   Observations: 32
#
# Change in ESG Coefficients (absolute change from t-6 to t-1):
#   ΔE: -0.0403*** (p=0.0000)
#   ΔS: 0.0304** (p=0.0140)
#   ΔG: -0.0020 (p=0.7368)
#
# Lagged ESG Levels (t-1):
#   E(t-1): 0.0279** (p=0.0235)
#   S(t-1): -0.0035 (p=0.6528)
#   G(t-1): -0.0087* (p=0.0947)
#
# Control Variables:
#   ROA: 1.9016* (p=0.0855)
#   Size: -0.0545 (p=0.2574)
#   Leverage: 3.9184*** (p=0.0001)
#
# ✓ Saved coefficients table to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/change_esg_coefficients.xlsx
# ✓ Saved significance table to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/change_esg_significance.xlsx
# ✓ Saved detailed tables to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/change_esg_detailed.xlsx
#
# ...
#     Observations: 152
#     ✓ R² = 0.407617 (Δ = +0.000000)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   LOG TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.482715 (Δ = +0.075097)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 33.3%
#         E_change: ✓
#         S_change: ✗
#         G_change: ✗
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.447493 (Δ = +0.039875)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 66.7%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✗
#
#   INVERSE TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.530419 (Δ = +0.122802)
#       Sign consistency (expected opposite): 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 0.0%
#         E_change: ✗
#         S_change: ✗
#         G_change: ✗
#
#   BOX-COX TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.529826 (Δ = +0.122209)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 0.0%
#         E_change: ✗
#         S_change: ✗
#         G_change: ✗
#
#   ----------------------------------------
#   CHANGE MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.407617, 0.530419]
#   R² stability (max-min): 0.122802
#   Average sign consistency (excluding Inverse): 100.0%
#   Inverse sign consistency (should be 0% if flipping correctly): 100.0%
#   Average significance consistency: 40.0%
#
# ================================================================================
# MODEL 18/20: change_model_17_5yr_absolute_All...
# ================================================================================
# Period: 5yr, Sector: All, Type: absolute
# Include levels: True
# Original R² = 0.481795, N = 152
# Using All Sectors: 388 observations
#   Found E_chg5_aligned: 152 non-null obs
#   Found S_chg5_aligned: 152 non-null obs
#   Found G_chg5_aligned: 152 non-null obs
# Change variables: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
# Level variables: ['E_lag1', 'S_lag1', 'G_lag1']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.481795 (Δ = +0.000000)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   LOG TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.578798 (Δ = +0.097003)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.533128 (Δ = +0.051334)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   INVERSE TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.640086 (Δ = +0.158292)
#       Sign consistency (expected opposite): 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   BOX-COX TRANSFORMATION:
#     Observations: 152
#     ✓ R² = 0.639350 (Δ = +0.157555)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   ----------------------------------------
#   CHANGE MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.481795, 0.640086]
#   R² stability (max-min): 0.158292
#   Average sign consistency (excluding Inverse): 100.0%
#   Inverse sign consistency (should be 0% if flipping correctly): 100.0%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 19/20: change_model_18_5yr_absolute_CS...
# ================================================================================
# Period: 5yr, Sector: CS, Type: absolute
# Include levels: False
# Original R² = 0.797869, N = 32
# Filtered to Consumer Staples: 80 observations
#   Found E_chg5_aligned: 32 non-null obs
#   Found S_chg5_aligned: 32 non-null obs
#   Found G_chg5_aligned: 32 non-null obs
# Change variables: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.797869 (Δ = +0.000000)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   LOG TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.829280 (Δ = +0.031411)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.817758 (Δ = +0.019889)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   INVERSE TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.830611 (Δ = +0.032742)
#       Sign consistency (expected opposite): 66.7%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✗
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   BOX-COX TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.830830 (Δ = +0.032961)
#       Sign consistency: 66.7%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✗
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   ----------------------------------------
#   CHANGE MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.797869, 0.830830]
#   R² stability (max-min): 0.032961
#   Average sign consistency (excluding Inverse): 91.7%
#   Inverse sign consistency (should be 0% if flipping correctly): 66.7%
#   Average significance consistency: 100.0%
#
# ================================================================================
# MODEL 20/20: change_model_19_5yr_absolute_CS...
# ================================================================================
# Period: 5yr, Sector: CS, Type: absolute
# Include levels: True
# Original R² = 0.846739, N = 32
# Filtered to Consumer Staples: 80 observations
#   Found E_chg5_aligned: 32 non-null obs
#   Found S_chg5_aligned: 32 non-null obs
#   Found G_chg5_aligned: 32 non-null obs
# Change variables: ['E_chg5_aligned', 'S_chg5_aligned', 'G_chg5_aligned']
# Level variables: ['E_lag1', 'S_lag1', 'G_lag1']
# Control variables: ['ROA', 'Size', 'Leverage']
#
#   ORIGINAL TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.846739 (Δ = +0.000000)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   LOG TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.876567 (Δ = +0.029828)
#       Sign consistency: 83.3%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✗
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   SQUARE ROOT TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.865689 (Δ = +0.018950)
#       Sign consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#         E_level: ✓
#         S_level: ✓
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   INVERSE TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.878216 (Δ = +0.031477)
#       Sign consistency (expected opposite): 66.7%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✗
#         E_level: ✓
#         S_level: ✗
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   BOX-COX TRANSFORMATION:
#     Observations: 32
#     ✓ R² = 0.878405 (Δ = +0.031666)
#       Sign consistency: 66.7%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✗
#         E_level: ✓
#         S_level: ✗
#         G_level: ✓
#       Significance consistency: 100.0%
#         E_change: ✓
#         S_change: ✓
#         G_change: ✓
#
#   ----------------------------------------
#   CHANGE MODEL CONSISTENCY SUMMARY
#   ----------------------------------------
#   R² range: [0.846739, 0.878405]
#   R² stability (max-min): 0.031666
#   Average sign consistency (excluding Inverse): 87.5%
#   Inverse sign consistency (should be 0% if flipping correctly): 66.7%
#   Average significance consistency: 100.0%
#
# ====================================================================================================
# OVERALL ROBUSTNESS SUMMARY - ESG CHANGE MODELS
# ====================================================================================================
#
# ====================================================================================================
# ESG CHANGE MODELS - ROBUSTNESS SUMMARY BY PERIOD
# ====================================================================================================
#
# ──────────────────────────────────────────────────
# PERIOD: 1-YEAR CHANGE (4 models)
# ──────────────────────────────────────────────────
#
#   Model: All Sector, Levels=False
#     Original R²: 0.408184
#     R² range: [0.408184, 0.516804] (Δ=0.108620)
#     Sign consistency: 83.3%
#     Inverse sign: 66.7%
#     Sig consistency: 100.0%
#
#   Model: All Sector, Levels=True
#     Original R²: 0.471497
#     R² range: [0.471497, 0.619626] (Δ=0.148129)
#     Sign consistency: 95.8%
#     Inverse sign: 83.3%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=False
#     Original R²: 0.309493
#     R² range: [0.309493, 0.373147] (Δ=0.063654)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=True
#     Original R²: 0.516191
#     R² range: [0.516191, 0.654526] (Δ=0.138335)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
# ──────────────────────────────────────────────────
# PERIOD: 2-YEAR CHANGE (4 models)
# ──────────────────────────────────────────────────
#
#   Model: All Sector, Levels=False
#     Original R²: 0.401390
#     R² range: [0.401390, 0.520192] (Δ=0.118803)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 86.7%
#
#   Model: All Sector, Levels=True
#     Original R²: 0.469578
#     R² range: [0.469578, 0.635852] (Δ=0.166275)
#     Sign consistency: 87.5%
#     Inverse sign: 83.3%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=False
#     Original R²: 0.439865
#     R² range: [0.439865, 0.459522] (Δ=0.019657)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=True
#     Original R²: 0.613603
#     R² range: [0.613603, 0.709991] (Δ=0.096388)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
# ──────────────────────────────────────────────────
# PERIOD: 3-YEAR CHANGE (4 models)
# ──────────────────────────────────────────────────
#
#   Model: All Sector, Levels=False
#     Original R²: 0.396433
#     R² range: [0.396433, 0.525442] (Δ=0.129009)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 53.3%
#
#   Model: All Sector, Levels=True
#     Original R²: 0.464953
#     R² range: [0.464953, 0.638998] (Δ=0.174044)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=False
#     Original R²: 0.477781
#     R² range: [0.477781, 0.508027] (Δ=0.030245)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=True
#     Original R²: 0.669627
#     R² range: [0.669627, 0.768435] (Δ=0.098808)
#     Sign consistency: 87.5%
#     Inverse sign: 83.3%
#     Sig consistency: 86.7%
#
# ──────────────────────────────────────────────────
# PERIOD: 4-YEAR CHANGE (4 models)
# ──────────────────────────────────────────────────
#
#   Model: All Sector, Levels=False
#     Original R²: 0.406210
#     R² range: [0.406210, 0.532211] (Δ=0.126001)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 86.7%
#
#   Model: All Sector, Levels=True
#     Original R²: 0.476894
#     R² range: [0.476894, 0.645269] (Δ=0.168375)
#     Sign consistency: 79.2%
#     Inverse sign: 66.7%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=False
#     Original R²: 0.706646
#     R² range: [0.704662, 0.718258] (Δ=0.013597)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=True
#     Original R²: 0.843119
#     R² range: [0.843119, 0.876589] (Δ=0.033471)
#     Sign consistency: 95.8%
#     Inverse sign: 83.3%
#     Sig consistency: 80.0%
#
# ──────────────────────────────────────────────────
# PERIOD: 5-YEAR CHANGE (4 models)
# ──────────────────────────────────────────────────
#
#   Model: All Sector, Levels=False
#     Original R²: 0.407617
#     R² range: [0.407617, 0.530419] (Δ=0.122802)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 40.0%
#
#   Model: All Sector, Levels=True
#     Original R²: 0.481795
#     R² range: [0.481795, 0.640086] (Δ=0.158292)
#     Sign consistency: 100.0%
#     Inverse sign: 100.0%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=False
#     Original R²: 0.797869
#     R² range: [0.797869, 0.830830] (Δ=0.032961)
#     Sign consistency: 91.7%
#     Inverse sign: 66.7%
#     Sig consistency: 100.0%
#
#   Model: CS Sector, Levels=True
#     Original R²: 0.846739
#     R² range: [0.846739, 0.878405] (Δ=0.031666)
#     Sign consistency: 87.5%
#     Inverse sign: 66.7%
#     Sig consistency: 100.0%
#
# ============================================================
# AVERAGE ROBUSTNESS BY PERIOD
# ============================================================
#         Sign_Consistency_%  Inverse_%  Sig_Consistency_%  Avg_R2_Range
# period
# 1                     94.8       87.5              100.0           0.1
# 2                     96.9       95.8               96.7           0.1
# 3                     96.9       95.8               85.0           0.1
# 4                     93.8       87.5               91.7           0.1
# 5                     94.8       83.4               85.0           0.1
#
# ============================================================
# OVERALL ROBUSTNESS ASSESSMENT
# ============================================================
#
# Average sign consistency across all models: 95.4%
# Average significance consistency: 91.7%
# Average R² range: 0.098957
#
# ✅ CHANGE MODELS ARE HIGHLY ROBUST
#
# ====================================================================================================
# EXPORTING ROBUSTNESS RESULTS TO EXCEL
# ====================================================================================================
#
# ✓ Robustness results exported to: /content/drive/MyDrive/Colab Notebooks/FTSE Data/aligned_change_output/change_model_robustness_all_periods_20260215_181614.xlsx
#
# ====================================================================================================
# ROBUSTNESS CHECKS COMPLETE - ESG CHANGE MODELS (ALL PERIODS 1-5)
# ====================================================================================================
